# %%
import pandas as pd
import numpy as np

# %%
##atp_2015 is now 2016 and 2017 pre wimbledon but the variable name has not changed
##atp_2015 is now 2016 and 2017 pre wimbledon but the variable name has not changed
##atp_2015 is now 2016 and 2017 pre wimbledon but the variable name has not changed
##atp_2015 is now 2016 and 2017 pre wimbledon but the variable name has not changed

# %%
atp_2016 = pd.read_csv("atp_2016.csv")
atp_2017_pre_wim = pd.read_csv("atp_2017_pre_wim.csv")
atp_2015 = pd.concat([atp_2016, atp_2017_pre_wim])
atp_2015.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2016-M020     Brisbane    Hard       32.0             A    20160104.0
# 1  2016-M020     Brisbane    Hard       32.0             A    20160104.0
# 2  2016-M020     Brisbane    Hard       32.0             A    20160104.0
# 3  2016-M020     Brisbane    Hard       32.0             A    20160104.0
# 4  2016-M020     Brisbane    Hard       32.0             A    20160104.0
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 0      300.0   105683.0          4.0          NaN    ...          1.0   7.0
# 1      299.0   103819.0          1.0          NaN    ...          1.0   2.0
# 2      298.0   105683.0          4.0          NaN    ...          4.0  10.0
# 3      297.0   103819.0          1.0          NaN    ...          1.0   8.0
# 4      296.0   106233.0          8.0          NaN    ...          2.0  11.0
#
#    l_df l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved l_bpFaced
# 0   3.0   61.0     34.0      25.0      14.0     10.0        3.0       5.0
# 1   4.0   55.0     31.0      18.0       9.0      8.0        2.0       6.0
# 2   3.0   84.0     54.0      41.0      16.0     12.0        2.0       2.0
# 3   2.0  104.0     62.0      46.0      21.0     16.0        8.0      11.0
# 4   2.0   98.0     52.0      41.0      27.0     15.0        7.0       8.0
#
# [5 rows x 49 columns]

# %%
atp_2015.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
surface_grass = atp_2015['surface'] == "Grass"
surface_clay = atp_2015["surface"]=="Clay"
surface_hard = atp_2015["surface"]=="Hard"
surface_clay_df = atp_2015[surface_clay]
surface_hard_df = atp_2015[surface_hard]
surface_df = atp_2015[surface_grass]

# %%
player_win_right = atp_2015["winner_hand"] == "R"
player_winners_right_df = atp_2015[player_win_right]
player_loser_right = atp_2015["loser_hand"] =="R"
player_loser_right_df = atp_2015[player_loser_right]
player_win_left = atp_2015["winner_hand"] == "L"
player_winner_left_df = atp_2015[player_win_left]
player_loser_left = atp_2015["loser_hand"] =="L"
player_loser_left_df = atp_2015[player_loser_left]

# %%
winners_right = pd.DataFrame(player_loser_right_df["winner_name"].value_counts())
losers_right = pd.DataFrame(player_winners_right_df["loser_name"].value_counts())

# %%
winners_left = pd.DataFrame(player_loser_left_df["winner_name"].value_counts())
losers_left = pd.DataFrame(player_winner_left_df["loser_name"].value_counts())

# %%
combined_RL1 = winners_left.join(losers_left, how = "outer")
combined_RL_Left = combined_RL1.fillna(0)
combined_RL_Left = combined_RL_Left.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
combined_RL_Left["Left_hand_win_pct"] = combined_RL_Left["wins"]/(combined_RL_Left["wins"]+combined_RL_Left["losses"])
combined_RL_Left.head()
# Out:
#                   wins  losses  Left_hand_win_pct
# Adrian Mannarino   6.0     6.0           0.500000
# Adrian Ungur       0.0     1.0           0.000000
# Agustin Velotti    0.0     1.0           0.000000
# Albert Montanes    1.0     6.0           0.142857
# Albert Ramos      10.0     5.0           0.666667

# %%
combined_RL = winners_right.join(losers_right,how = "outer")
combined_RL_Right = combined_RL.fillna(0)
combined_RL_Right= combined_RL_Right.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
combined_RL_Right["right_hand_win_pct"] = combined_RL_Right["wins"]/(combined_RL_Right["wins"]+combined_RL_Right["losses"])
combined_RL_Right.head()
# Out:
#                       wins  losses  right_hand_win_pct
# Abdullah Maqdas        0.0     2.0            0.000000
# Adam Hornby            0.0     1.0            0.000000
# Adam Pavlasek          4.0     8.0            0.333333
# Aditya Hari Sasongko   0.0     1.0            0.000000
# Adrian Mannarino      34.0    38.0            0.472222

# %%
# combined_RL_Right.head()

# %%
del combined_RL_Right["wins"]
del combined_RL_Left["wins"]
del combined_RL_Right["losses"]
del combined_RL_Left["losses"]

# %%
surface_df.head()
# Out:
#      tourney_id     tourney_name surface  draw_size tourney_level  \
# 1348  2016-M010  s-Hertogenbosch   Grass       32.0             A
# 1349  2016-M010  s-Hertogenbosch   Grass       32.0             A
# 1350  2016-M010  s-Hertogenbosch   Grass       32.0             A
# 1351  2016-M010  s-Hertogenbosch   Grass       32.0             A
# 1352  2016-M010  s-Hertogenbosch   Grass       32.0             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry    ...     \
# 1348    20160606.0      300.0   103917.0          8.0          NaN    ...
# 1349    20160606.0      299.0   104180.0          7.0          NaN    ...
# 1350    20160606.0      298.0   103917.0          8.0          NaN    ...
# 1351    20160606.0      297.0   104180.0          7.0          NaN    ...
# 1352    20160606.0      296.0   103333.0          3.0          NaN    ...
#
#      w_bpFaced l_ace  l_df l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 1348       4.0   9.0   1.0   62.0     38.0      25.0      10.0     10.0
# 1349       0.0  21.0   6.0   72.0     47.0      42.0      15.0     12.0
# 1350       2.0  19.0   1.0   98.0     64.0      50.0      20.0     16.0
# 1351       5.0   3.0   3.0  102.0     63.0      45.0      29.0     16.0
# 1352       3.0   4.0   5.0   54.0     30.0      24.0      10.0      9.0
#
#       l_bpSaved l_bpFaced
# 1348        0.0       3.0
# 1349        0.0       0.0
# 1350        6.0       8.0
# 1351        4.0       5.0
# 1352        4.0       6.0
#
# [5 rows x 49 columns]

# %%
winners_clay = pd.DataFrame(surface_clay_df["winner_name"].value_counts())
losers_clay = pd.DataFrame(surface_clay_df["loser_name"].value_counts())
winners_hard = pd.DataFrame(surface_hard_df["winner_name"].value_counts())
losers_hard = pd.DataFrame(surface_hard_df["loser_name"].value_counts())
winners_grass = pd.DataFrame(surface_df["winner_name"].value_counts())
losers_grass = pd.DataFrame(surface_df["loser_name"].value_counts())

# %%
winners_clay = winners_clay.reset_index()
losers_clay = losers_clay.reset_index()
winners_hard = winners_hard.reset_index()
losers_hard = losers_hard.reset_index()
winner_grass = winners_grass.reset_index()
losers_grass = losers_grass.reset_index()

# %%
merged_win_lose_clay = pd.merge(winners_clay, losers_clay, how ="outer")
merged_win_lose_hard = pd.merge(winners_hard, losers_hard, how = "outer")
merged_win_lose_grass = pd.merge(winner_grass, losers_grass, how = "outer")

# %%
merged_win_lose_clay = merged_win_lose_clay.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
merged_win_lose_hard = merged_win_lose_hard.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
merged_win_lose_grass = merged_win_lose_grass.rename(index=str, columns={"winner_name": "wins","loser_name":"losses"})

# %%
merged_win_lose_clay = merged_win_lose_clay.fillna(0)
merged_win_lose_hard  = merged_win_lose_hard.fillna(0)
merged_win_lose_grass = merged_win_lose_grass.fillna(0)

# %%
merged_win_lose_grass["win_pct_grass"] = merged_win_lose_grass["wins"]/(merged_win_lose_grass["wins"]+merged_win_lose_grass["losses"])
merged_win_lose_clay["win_pct_clay"] = merged_win_lose_clay["wins"]/(merged_win_lose_clay["wins"]+merged_win_lose_clay["losses"])
merged_win_lose_hard["win_pct_hard"] = merged_win_lose_hard["wins"]/(merged_win_lose_hard["wins"]+merged_win_lose_hard["losses"])

# %%
merged_win_lose_grass = merged_win_lose_grass.set_index("index")
merged_win_lose_hard = merged_win_lose_hard.set_index("index")
merged_win_lose_clay = merged_win_lose_clay.set_index("index")

# %%
del merged_win_lose_grass["wins"]
del merged_win_lose_grass["losses"]
del merged_win_lose_clay["wins"]
del merged_win_lose_clay["losses"]
del merged_win_lose_hard["wins"]
del merged_win_lose_hard["losses"]

# %%
merged_win_lose_hard.head()
# Out:
#                  win_pct_hard
# index
# Novak Djokovic       0.863636
# Andy Murray          0.876923
# Kei Nishikori        0.732394
# David Goffin         0.666667
# Grigor Dimitrov      0.694444

# %%
players = atp_2015["winner_name"]

# %%
players_list = players.unique()

# %%
##change players_list to players_list_test for testing
stat_player_df = pd.DataFrame({'name':players_list})

# %%
len(stat_player_df)
# Out:
# 301

# %%
grouped_atp_2015 = atp_2015.groupby(["winner_name"])

# %%
aces = grouped_atp_2015["w_ace"].sum()
service_games = grouped_atp_2015["w_SvGms"].sum()
first_serve_in = grouped_atp_2015["w_1stIn"].sum()
first_serves_won = grouped_atp_2015["w_1stWon"].sum()
doubfts = grouped_atp_2015["w_df"].sum()
total_brk_saved = grouped_atp_2015["w_bpSaved"].sum()
total_brk_faced = grouped_atp_2015["w_bpFaced"].sum()
rt_games_total = grouped_atp_2015["l_SvGms"].sum()
break_point_opp_total = grouped_atp_2015["l_bpFaced"].sum()
break_point_opp_loss = grouped_atp_2015["l_bpSaved"].sum()
svpt_total = grouped_atp_2015["w_svpt"].sum()

# %%
grouped_atp_2015_losers = atp_2015.groupby(["loser_name"])

# %%
aces_1 = grouped_atp_2015_losers["l_ace"].sum()
service_games_1 = grouped_atp_2015_losers["l_SvGms"].sum()
first_serve_in_l = grouped_atp_2015_losers["l_1stIn"].sum()
first_serves_won_l = grouped_atp_2015_losers["l_1stWon"].sum()
doubfts_l = grouped_atp_2015_losers["l_df"].sum()
total_brk_saved_l = grouped_atp_2015_losers["l_bpSaved"].sum()
total_brk_faced_l = grouped_atp_2015_losers["l_bpFaced"].sum()
rt_games_total_l = grouped_atp_2015_losers["w_SvGms"].sum()
break_point_opp_total_l = grouped_atp_2015_losers["w_bpFaced"].sum()
break_point_opp_loss_l = grouped_atp_2015_losers["w_bpSaved"].sum()
svpt_total_l = grouped_atp_2015_losers["l_svpt"].sum()

# %%
updated_stats_players_l = pd.DataFrame({"aces":aces_1,
                                   "service_games":service_games_1,
                                     "first_serve_in": first_serve_in_l,
                                     "first_serves_won": first_serves_won_l,
                                     "doubfts": doubfts_l,
                                     "total_brk_saved": total_brk_saved_l,
                                     "total_brk_faced": total_brk_faced_l,
                                     "rt_games_total": rt_games_total_l,
                                     "break_point_opp_total": break_point_opp_total_l,
                                     "break_point_opp_loss": break_point_opp_loss_l,
                                     "svpt_total": svpt_total_l})
updated_stats_players_l.head(20)
# Out:
#                                   aces  break_point_opp_loss  \
# loser_name
# Abdullah Maqdas                    5.0                  23.0
# Adam Hornby                        2.0                   2.0
# Adam Pavlasek                     51.0                  12.0
# Aditya Hari Sasongko               3.0                   3.0
# Adrian Mannarino                 159.0                 142.0
# Adrian Menendez Maceiras           1.0                   5.0
# Adrian Ungur                       6.0                  18.0
# Adrien Bossel                      3.0                   0.0
# Agustin Velotti                    9.0                  16.0
# Akira Santillan                   18.0                  10.0
# Albano Olivetti                   56.0                   1.0
# Albert Montanes                   31.0                  13.0
# Albert Ramos                     187.0                 165.0
# Alberto Emmanuel Alvarado Larin    1.0                   6.0
# Alberto Lim                       10.0                  12.0
# Aldin Setkic                       6.0                   1.0
# Alejandro Falla                    4.0                   4.0
# Alejandro Gonzalez                11.0                   8.0
# Aleksandr Nedovyesov               9.0                   1.0
# Alessandro Giannessi              23.0                  20.0
#
#                                  break_point_opp_total  doubfts  \
# loser_name
# Abdullah Maqdas                                   32.0      4.0
# Adam Hornby                                        3.0      7.0
# Adam Pavlasek                                     22.0     30.0
# Aditya Hari Sasongko                               4.0      3.0
# Adrian Mannarino                                 216.0    132.0
# Adrian Menendez Maceiras                           6.0      2.0
# Adrian Ungur                                      27.0     14.0
# Adrien Bossel                                      0.0      2.0
# Agustin Velotti                                   19.0      4.0
# Akira Santillan                                   11.0     11.0
# Albano Olivetti                                    1.0     17.0
# Albert Montanes                                   21.0     27.0
# Albert Ramos                                     256.0    142.0
# Alberto Emmanuel Alvarado Larin                   12.0      6.0
# Alberto Lim                                       20.0     10.0
# Aldin Setkic                                       2.0      8.0
# Alejandro Falla                                    7.0      2.0
# Alejandro Gonzalez                                16.0      8.0
# Aleksandr Nedovyesov                               4.0      4.0
# Alessandro Giannessi                              27.0     25.0
#
#                                  first_serve_in  first_serves_won  \
# loser_name
# Abdullah Maqdas                           247.0             149.0
# Adam Hornby                                53.0              30.0
# Adam Pavlasek                             385.0             254.0
# Aditya Hari Sasongko                       53.0              32.0
# Adrian Mannarino                         1948.0            1264.0
# Adrian Menendez Maceiras                   38.0              18.0
# Adrian Ungur                              240.0             142.0
# Adrien Bossel                              42.0              30.0
# Agustin Velotti                            72.0              48.0
# Akira Santillan                           117.0              78.0
# Albano Olivetti                           128.0             108.0
# Albert Montanes                           424.0             282.0
# Albert Ramos                             2490.0            1603.0
# Alberto Emmanuel Alvarado Larin           129.0              58.0
# Alberto Lim                               174.0             106.0
# Aldin Setkic                               93.0              58.0
# Alejandro Falla                            68.0              41.0
# Alejandro Gonzalez                        166.0             100.0
# Aleksandr Nedovyesov                       47.0              32.0
# Alessandro Giannessi                      278.0             181.0
#
#                                  rt_games_total  service_games  svpt_total  \
# loser_name
# Abdullah Maqdas                            46.0           46.0       316.0
# Adam Hornby                                13.0           13.0        82.0
# Adam Pavlasek                              90.0           89.0       660.0
# Aditya Hari Sasongko                       13.0           13.0        79.0
# Adrian Mannarino                          477.0          468.0      3234.0
# Adrian Menendez Maceiras                   12.0           12.0        76.0
# Adrian Ungur                               57.0           56.0       384.0
# Adrien Bossel                              11.0           10.0        76.0
# Agustin Velotti                            23.0           22.0       138.0
# Akira Santillan                            38.0           38.0       234.0
# Albano Olivetti                            36.0           35.0       218.0
# Albert Montanes                           113.0          110.0       693.0
# Albert Ramos                              599.0          584.0      4063.0
# Alberto Emmanuel Alvarado Larin            26.0           24.0       177.0
# Alberto Lim                                42.0           41.0       265.0
# Aldin Setkic                               16.0           15.0       133.0
# Alejandro Falla                            19.0           18.0       117.0
# Alejandro Gonzalez                         42.0           42.0       286.0
# Aleksandr Nedovyesov                       13.0           13.0        77.0
# Alessandro Giannessi                       60.0           61.0       437.0
#
#                                  total_brk_faced  total_brk_saved
# loser_name
# Abdullah Maqdas                             33.0             19.0
# Adam Hornby                                 11.0              4.0
# Adam Pavlasek                               78.0             39.0
# Aditya Hari Sasongko                        14.0              8.0
# Adrian Mannarino                           367.0            195.0
# Adrian Menendez Maceiras                    11.0              4.0
# Adrian Ungur                                49.0             30.0
# Adrien Bossel                               10.0              8.0
# Agustin Velotti                             12.0              6.0
# Akira Santillan                             20.0              9.0
# Albano Olivetti                             13.0             11.0
# Albert Montanes                             66.0             35.0
# Albert Ramos                               427.0            233.0
# Alberto Emmanuel Alvarado Larin             35.0             18.0
# Alberto Lim                                 26.0             12.0
# Aldin Setkic                                14.0             10.0
# Alejandro Falla                             17.0              8.0
# Alejandro Gonzalez                          31.0             18.0
# Aleksandr Nedovyesov                         8.0              3.0
# Alessandro Giannessi                        47.0             29.0

# %%
updated_stats_players = pd.DataFrame({"aces":aces,
                                   "service_games":service_games,
                                     "first_serve_in": first_serve_in,
                                     "first_serves_won": first_serves_won,
                                     "doubfts": doubfts,
                                     "total_brk_saved": total_brk_saved,
                                     "total_brk_faced": total_brk_faced,
                                     "rt_games_total": rt_games_total,
                                     "break_point_opp_total": break_point_opp_total,
                                     "break_point_opp_loss": break_point_opp_loss,
                                     "svpt_total": svpt_total})
updated_stats_players.head()
# Out:
#                        aces  break_point_opp_loss  break_point_opp_total  \
# winner_name
# Adam Pavlasek          30.0                  24.0                   46.0
# Adrian Mannarino      224.0                 214.0                  383.0
# Adrian Ungur            5.0                   4.0                   16.0
# Aisam Ul Haq Qureshi   22.0                   7.0                   13.0
# Albert Montanes        21.0                  40.0                   70.0
#
#                       doubfts  first_serve_in  first_serves_won  \
# winner_name
# Adam Pavlasek            13.0           234.0             174.0
# Adrian Mannarino        103.0          2047.0            1499.0
# Adrian Ungur              3.0           126.0              85.0
# Aisam Ul Haq Qureshi      5.0            34.0              31.0
# Albert Montanes          22.0           270.0             213.0
#
#                       rt_games_total  service_games  svpt_total  \
# winner_name
# Adam Pavlasek                   38.0           40.0       379.0
# Adrian Mannarino               469.0          477.0      3415.0
# Adrian Ungur                    30.0           30.0       202.0
# Aisam Ul Haq Qureshi            11.0           12.0        64.0
# Albert Montanes                 80.0           79.0       472.0
#
#                       total_brk_faced  total_brk_saved
# winner_name
# Adam Pavlasek                    29.0             21.0
# Adrian Mannarino                230.0            147.0
# Adrian Ungur                     18.0             12.0
# Aisam Ul Haq Qureshi              1.0              1.0
# Albert Montanes                  25.0             16.0

# %%
frames = [updated_stats_players,updated_stats_players_l]

# %%
results = pd.concat(frames)

# %%
results = results.reset_index()

# %%
full_player_stats = results.groupby(["index"])

# %%
len(full_player_stats.groups)
# Out:
# 463

# %%
total_player_stats = full_player_stats.sum()

# %%
total_player_stats["ace_pct"] = total_player_stats["aces"]/total_player_stats["svpt_total"]
total_player_stats["df_pct"] = total_player_stats["doubfts"]/total_player_stats["svpt_total"]
total_player_stats["first_serve_won_pct"] = total_player_stats["first_serves_won"]/total_player_stats["first_serve_in"]
total_player_stats["broken_pct"] = (total_player_stats["total_brk_faced"]-total_player_stats["total_brk_saved"])/total_player_stats["service_games"]
total_player_stats["breaking_pct"] = (total_player_stats["break_point_opp_total"]-total_player_stats["break_point_opp_loss"])/total_player_stats["rt_games_total"]
total_player_stats["break_conversion_pct"] = (total_player_stats["break_point_opp_total"]-total_player_stats["break_point_opp_loss"])/total_player_stats["break_point_opp_total"]

# %%
total_player_stats = total_player_stats.fillna(0)
total_player_stats.head()
# Out:
#                        aces  break_point_opp_loss  break_point_opp_total  \
# index
# Abdullah Maqdas         5.0                  23.0                   32.0
# Adam Hornby             2.0                   2.0                    3.0
# Adam Pavlasek          81.0                  36.0                   68.0
# Aditya Hari Sasongko    3.0                   3.0                    4.0
# Adrian Mannarino      383.0                 356.0                  599.0
#
#                       doubfts  first_serve_in  first_serves_won  \
# index
# Abdullah Maqdas           4.0           247.0             149.0
# Adam Hornby               7.0            53.0              30.0
# Adam Pavlasek            43.0           619.0             428.0
# Aditya Hari Sasongko      3.0            53.0              32.0
# Adrian Mannarino        235.0          3995.0            2763.0
#
#                       rt_games_total  service_games  svpt_total  \
# index
# Abdullah Maqdas                 46.0           46.0       316.0
# Adam Hornby                     13.0           13.0        82.0
# Adam Pavlasek                  128.0          129.0      1039.0
# Aditya Hari Sasongko            13.0           13.0        79.0
# Adrian Mannarino               946.0          945.0      6649.0
#
#                       total_brk_faced  total_brk_saved   ace_pct    df_pct  \
# index
# Abdullah Maqdas                  33.0             19.0  0.015823  0.012658
# Adam Hornby                      11.0              4.0  0.024390  0.085366
# Adam Pavlasek                   107.0             60.0  0.077960  0.041386
# Aditya Hari Sasongko             14.0              8.0  0.037975  0.037975
# Adrian Mannarino                597.0            342.0  0.057603  0.035344
#
#                       first_serve_won_pct  broken_pct  breaking_pct  \
# index
# Abdullah Maqdas                  0.603239    0.304348      0.195652
# Adam Hornby                      0.566038    0.538462      0.076923
# Adam Pavlasek                    0.691438    0.364341      0.250000
# Aditya Hari Sasongko             0.603774    0.461538      0.076923
# Adrian Mannarino                 0.691615    0.269841      0.256871
#
#                       break_conversion_pct
# index
# Abdullah Maqdas                   0.281250
# Adam Hornby                       0.333333
# Adam Pavlasek                     0.470588
# Aditya Hari Sasongko              0.250000
# Adrian Mannarino                  0.405676

# %%
total_player_stats = total_player_stats.join(merged_win_lose_grass,how = "outer")

# %%
total_player_stats = total_player_stats.join(merged_win_lose_clay, how = "outer")
total_player_stats = total_player_stats.join(merged_win_lose_hard, how = "outer")
total_player_stats = total_player_stats.join(combined_RL_Left, how = "outer")
total_player_stats = total_player_stats.join(combined_RL_Right, how = "outer")

# %%
total_player_stats = total_player_stats.fillna(0)

# %%
total_player_stats.head()
# Out:
#                        aces  break_point_opp_loss  break_point_opp_total  \
# Abdullah Maqdas         5.0                  23.0                   32.0
# Adam Hornby             2.0                   2.0                    3.0
# Adam Pavlasek          81.0                  36.0                   68.0
# Aditya Hari Sasongko    3.0                   3.0                    4.0
# Adrian Mannarino      383.0                 356.0                  599.0
#
#                       doubfts  first_serve_in  first_serves_won  \
# Abdullah Maqdas           4.0           247.0             149.0
# Adam Hornby               7.0            53.0              30.0
# Adam Pavlasek            43.0           619.0             428.0
# Aditya Hari Sasongko      3.0            53.0              32.0
# Adrian Mannarino        235.0          3995.0            2763.0
#
#                       rt_games_total  service_games  svpt_total  \
# Abdullah Maqdas                 46.0           46.0       316.0
# Adam Hornby                     13.0           13.0        82.0
# Adam Pavlasek                  128.0          129.0      1039.0
# Aditya Hari Sasongko            13.0           13.0        79.0
# Adrian Mannarino               946.0          945.0      6649.0
#
#                       total_brk_faced         ...            df_pct  \
# Abdullah Maqdas                  33.0         ...          0.012658
# Adam Hornby                      11.0         ...          0.085366
# Adam Pavlasek                   107.0         ...          0.041386
# Aditya Hari Sasongko             14.0         ...          0.037975
# Adrian Mannarino                597.0         ...          0.035344
#
#                       first_serve_won_pct  broken_pct  breaking_pct  \
# Abdullah Maqdas                  0.603239    0.304348      0.195652
# Adam Hornby                      0.566038    0.538462      0.076923
# Adam Pavlasek                    0.691438    0.364341      0.250000
# Aditya Hari Sasongko             0.603774    0.461538      0.076923
# Adrian Mannarino                 0.691615    0.269841      0.256871
#
#                       break_conversion_pct  win_pct_grass  win_pct_clay  \
# Abdullah Maqdas                   0.281250           0.00           0.0
# Adam Hornby                       0.333333           0.00           0.0
# Adam Pavlasek                     0.470588           0.50           0.5
# Aditya Hari Sasongko              0.250000           0.00           0.0
# Adrian Mannarino                  0.405676           0.64           0.4
#
#                       win_pct_hard  Left_hand_win_pct  right_hand_win_pct
# Abdullah Maqdas           0.000000                0.0            0.000000
# Adam Hornby               0.000000                0.0            0.000000
# Adam Pavlasek             0.000000                0.0            0.333333
# Aditya Hari Sasongko      0.000000                0.0            0.000000
# Adrian Mannarino          0.422222                0.5            0.472222
#
# [5 rows x 22 columns]

# %%
##matchups_2016 is now matchups_2017_2018 but the variable name is not has not changed
##matchups_2016 is now matchups_2017_2018 but the variable name is not has not changed
##matchups_2016 is now matchups_2017_2018 but the variable name is not has not changed

# %%
##matchups_2016 is now matchups_2017_2018 but the variable name is not has not changed
atp_2017_post_wim = pd.read_csv("atp_2017_post_wim.csv")
atp_2018 = pd.read_csv("atp_2018.csv")
matchups_2016 = pd.concat([atp_2017_post_wim, atp_2018])

# %%
##separating wimbledon
wimbledon_matches = matchups_2016[matchups_2016.tourney_name == 'Wimbledon']
matchups_2016 = matchups_2016[matchups_2016.tourney_name != "Wimbledon"]
wimbledon_matches.head()
# Out:
#      tourney_id tourney_name surface  player_1_win          player_1  \
# 1035   2017-540    Wimbledon   Grass             0  Alexander Bublik
# 1036   2017-540    Wimbledon   Grass             0        Joao Sousa
# 1037   2017-540    Wimbledon   Grass             0   Illya Marchenko
# 1038   2017-540    Wimbledon   Grass             1     Fabio Fognini
# 1039   2017-540    Wimbledon   Grass             0      Nick Kyrgios
#
#      Player_1_hand  Player_1_age               player_2 Player_2_hand  \
# 1035             R     20.043806            Andy Murray             R
# 1036             R     28.260096           Dustin Brown             R
# 1037             R     29.817933            Jiri Vesely             L
# 1038             R     30.110883        Dmitry Tursunov             R
# 1039             R     22.184805  Pierre Hugues Herbert             R
#
#       Player_2_age
# 1035     30.135524
# 1036     32.566735
# 1037     23.980835
# 1038     34.557153
# 1039     26.294319

# %%
# matchups_2016 = matchups_2016[['Player 1.1', 'Player 2.1', 'Player_1_Win.1']]
matchups_2016.head()
# Out:
#   tourney_id tourney_name surface  player_1_win             player_1  \
# 0  2017-0316       Bastad    Clay             0  Alexandr Dolgopolov
# 1  2017-0316       Bastad    Clay             1  Alexandr Dolgopolov
# 2  2017-0316       Bastad    Clay             0    Fernando Verdasco
# 3  2017-0316       Bastad    Clay             1     Andrey Kuznetsov
# 4  2017-0316       Bastad    Clay             0      Karen Khachanov
#
#   Player_1_hand  Player_1_age                     player_2 Player_2_hand  \
# 0             R     28.689938                 David Ferrer             R
# 1             R     28.689938             Andrey Kuznetsov             R
# 2             L     33.670089                 David Ferrer             R
# 3             R     26.398357  Diego Sebastian Schwartzman             R
# 4             R     21.155373          Alexandr Dolgopolov             R
#
#    Player_2_age
# 0     35.290897
# 1     26.398357
# 2     35.290897
# 3     24.917180
# 4     28.689938

# %%
matchups_2016 = matchups_2016[['surface', 'player_1_win', 'player_1','player_2', 'Player_1_hand','Player_2_hand']]
# matchups_2016 = matchups_2016[['Player 1.1', 'Player 2.1', 'Player_1_Win.1']]
# matchups_2016.columns = [['player_1', 'player_2', "player_1_win"]]
matchups_2016.head()
# Out:
#   surface  player_1_win             player_1                     player_2  \
# 0    Clay             0  Alexandr Dolgopolov                 David Ferrer
# 1    Clay             1  Alexandr Dolgopolov             Andrey Kuznetsov
# 2    Clay             0    Fernando Verdasco                 David Ferrer
# 3    Clay             1     Andrey Kuznetsov  Diego Sebastian Schwartzman
# 4    Clay             0      Karen Khachanov          Alexandr Dolgopolov
#
#   Player_1_hand Player_2_hand
# 0             R             R
# 1             R             R
# 2             L             R
# 3             R             R
# 4             R             R

# %%
# matchups_2016['ace_pct'] = 0
# ace_pct = total_player_stats.loc['Roger Federer']['ace_pct'] - total_player_stats.loc['Milos Raonic']['ace_pct']
# print(type(ace_pct))
# matchups_2016.loc[0,'ace_pct'] = ace_pct
# matchups_2016.head()

# %%
matchups_2016['ace_pct'] = 0
matchups_2016['df_pct'] = 0
matchups_2016['first_serve_pct'] = 0
matchups_2016['broken_pct'] = 0
matchups_2016['breaking_pct'] = 0
matchups_2016['break_conversion_pct'] = 0
matchups_2016["surface_win_pct"] = 0
matchups_2016["player_hand_win_pct"] = 0
count_unknown_hand = 0

for index, row in matchups_2016.iterrows():
    player_1 = row['player_1']
    player_2 = row['player_2']
    if player_1 in total_player_stats.index and player_2 in total_player_stats.index:
        ace_pct = total_player_stats.loc[player_1]['ace_pct'] - total_player_stats.loc[player_2]['ace_pct']
        df_pct = total_player_stats.loc[player_1]['df_pct'] - total_player_stats.loc[player_2]['df_pct']
        first_serve_pct = total_player_stats.loc[player_1]['first_serve_won_pct'] - total_player_stats.loc[player_2]['first_serve_won_pct']
        broken_pct = total_player_stats.loc[player_1]['broken_pct'] - total_player_stats.loc[player_2]['broken_pct']
        breaking_pct = total_player_stats.loc[player_1]['breaking_pct'] - total_player_stats.loc[player_2]['breaking_pct']
        break_conversion_pct = total_player_stats.loc[player_1]['break_conversion_pct'] - total_player_stats.loc[player_2]['break_conversion_pct']
        if row["surface"] == "Hard":
            surface_win_pct = total_player_stats.loc[player_1]["win_pct_hard"]-total_player_stats.loc[player_2]["win_pct_hard"]
        elif row["surface"] == "Clay":
            surface_win_pct = total_player_stats.loc[player_1]["win_pct_clay"]-total_player_stats.loc[player_2]["win_pct_clay"]
        elif row["surface"] == "Grass":
            surface_win_pct = total_player_stats.loc[player_1]["win_pct_grass"]-total_player_stats.loc[player_2]["win_pct_grass"]
        else:
            print("something went wrong...")
        
        if row["Player_1_hand"] == "R":
            if row["Player_2_hand"] == "R":
                player_hand_win_pct = total_player_stats.loc[player_1]["right_hand_win_pct"]-total_player_stats.loc[player_2]["right_hand_win_pct"]
            elif row["Player_2_hand"] == "L":
                player_hand_win_pct = total_player_stats.loc[player_1]["Left_hand_win_pct"]-total_player_stats.loc[player_2]["right_hand_win_pct"]
            else:
                print("unknown")
                count_unknown_hand+=1   
        elif row["Player_1_hand"] == "L":
            if row["Player_2_hand"] == "R":
                player_hand_win_pct = total_player_stats.loc[player_1]["right_hand_win_pct"]-total_player_stats.loc[player_2]["Left_hand_win_pct"]
            elif row["Player_2_hand"] == "L":
                player_hand_win_pct = total_player_stats.loc[player_1]["Left_hand_win_pct"]-total_player_stats.loc[player_2]["Left_hand_win_pct"]
            else:
                print("unknown")
                count_unknown_hand+=1
            
            
        matchups_2016.loc[index, 'ace_pct'] =  ace_pct
        matchups_2016.loc[index, 'df_pct'] = df_pct
        matchups_2016.loc[index, 'first_serve_pct'] = first_serve_pct
        matchups_2016.loc[index, 'broken_pct'] = broken_pct
        matchups_2016.loc[index, 'breaking_pct'] =  breaking_pct
        matchups_2016.loc[index, 'break_conversion_pct'] = break_conversion_pct
        matchups_2016.loc[index, 'surface_win_pct'] = surface_win_pct
        matchups_2016.loc[index, "player_hand_win_pct"] = player_hand_win_pct
    else: 
        continue
    
len(matchups_2016)
# Out:
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# 2447

# %%
matchups_2016 = matchups_2016[matchups_2016.first_serve_pct != 0]
matchups_2016 = matchups_2016.replace([np.inf, -np.inf], np.nan)
len(matchups_2016)
# Out:
# 2349

# %%
matchups_2016.head()
# Out:
#   surface  player_1_win             player_1                     player_2  \
# 0    Clay             0  Alexandr Dolgopolov                 David Ferrer
# 1    Clay             1  Alexandr Dolgopolov             Andrey Kuznetsov
# 2    Clay             0    Fernando Verdasco                 David Ferrer
# 3    Clay             1     Andrey Kuznetsov  Diego Sebastian Schwartzman
# 4    Clay             0      Karen Khachanov          Alexandr Dolgopolov
#
#   Player_1_hand Player_2_hand   ace_pct    df_pct  first_serve_pct  \
# 0             R             R -0.074903  0.004973        -0.031930
# 1             R             R  0.091328 -0.002168         0.026147
# 2             L             R -0.057606  0.002780        -0.091490
# 3             R             R -0.010170 -0.002854        -0.011382
# 4             R             R -0.082056  0.004406        -0.031315
#
#    broken_pct  breaking_pct  break_conversion_pct  surface_win_pct  \
# 0    0.115524      0.012928              0.006386        -0.201136
# 1   -0.069470     -0.046227             -0.011295         0.069192
# 2    0.178378     -0.059082             -0.089444        -0.162500
# 3    0.040271     -0.022511              0.011092        -0.182249
# 4    0.109171      0.013037              0.003506        -0.370779
#
#    player_hand_win_pct
# 0            -0.272727
# 1             0.098059
# 2            -0.204545
# 3            -0.198179
# 4            -0.216634

# %%
parameter_match_ups = pd.read_csv('matchups_parameters_3.csv')

# %%
parameter_match_ups.head()
# Out:
#    Unnamed: 0       player_1         player_2  \
# 0           0  Roger Federer    Dominic Thiem
# 1           1  Roger Federer    Bernard Tomic
# 2           2  Roger Federer  Grigor Dimitrov
# 3           3  Roger Federer      Marin Cilic
# 4           4  Roger Federer    Lucas Pouille
#
#                                      player_1_losses  \
# 0  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 1  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 2  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 3  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 4  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
#
#                                        player_1_wins  \
# 0  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 1  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 2  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 3  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 4  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
#
#                                      player_2_losses  \
# 0  ['Roger Federer', 'Gilles Muller', 'David Goff...
# 1  ['Milos Raonic', 'Teymuraz Gabashvili', 'Andy ...
# 2  ['Roger Federer', 'Viktor Troicki', 'Roger Fed...
# 3  ['Dominic Thiem', 'Roberto Bautista Agut', 'Al...
# 4  ['Milos Raonic', 'Milos Raonic', 'Andrey Kuzne...
#
#                                        player_2_wins  \
# 0  ['Marin Cilic', 'Denis Kudla', 'James Duckwort...
# 1  ['Kei Nishikori', 'Radek Stepanek', 'Nicolas M...
# 2  ['Viktor Troicki', 'Gilles Simon', 'Gilles Mul...
# 3  ['Hyeon Chung', 'Thiemo De Bakker', 'Albert Ra...
# 4  ['David Goffin', 'Yoshihito Nishioka', 'David ...
#
#    player_1_losses_in_player_2_wins  player_2_losses_in_player_1_wins  \
# 0                                 2                                15
# 1                                 1                                 9
# 2                                 2                                12
# 3                                 2                                10
# 4                                 2                                 6
#
#    player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                              16                                   4
# 1                               6                                   2
# 2                              13                                   3
# 3                              12                                   3
# 4                              10                                   2
#
#    parameters_value
# 0          0.011765
# 1          0.010000
# 2          0.014286
# 3          0.016667
# 4          0.025000

# %%
del parameter_match_ups["Unnamed: 0"]

# %%
parameter_match_ups.head(5)
# Out:
#         player_1         player_2  \
# 0  Roger Federer    Dominic Thiem
# 1  Roger Federer    Bernard Tomic
# 2  Roger Federer  Grigor Dimitrov
# 3  Roger Federer      Marin Cilic
# 4  Roger Federer    Lucas Pouille
#
#                                      player_1_losses  \
# 0  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 1  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 2  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 3  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
# 4  ['Milos Raonic', 'Novak Djokovic', 'Jo Wilfrie...
#
#                                        player_1_wins  \
# 0  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 1  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 2  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 3  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
# 4  ['Dominic Thiem', 'Grigor Dimitrov', 'Tobias K...
#
#                                      player_2_losses  \
# 0  ['Roger Federer', 'Gilles Muller', 'David Goff...
# 1  ['Milos Raonic', 'Teymuraz Gabashvili', 'Andy ...
# 2  ['Roger Federer', 'Viktor Troicki', 'Roger Fed...
# 3  ['Dominic Thiem', 'Roberto Bautista Agut', 'Al...
# 4  ['Milos Raonic', 'Milos Raonic', 'Andrey Kuzne...
#
#                                        player_2_wins  \
# 0  ['Marin Cilic', 'Denis Kudla', 'James Duckwort...
# 1  ['Kei Nishikori', 'Radek Stepanek', 'Nicolas M...
# 2  ['Viktor Troicki', 'Gilles Simon', 'Gilles Mul...
# 3  ['Hyeon Chung', 'Thiemo De Bakker', 'Albert Ra...
# 4  ['David Goffin', 'Yoshihito Nishioka', 'David ...
#
#    player_1_losses_in_player_2_wins  player_2_losses_in_player_1_wins  \
# 0                                 2                                15
# 1                                 1                                 9
# 2                                 2                                12
# 3                                 2                                10
# 4                                 2                                 6
#
#    player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                              16                                   4
# 1                               6                                   2
# 2                              13                                   3
# 3                              12                                   3
# 4                              10                                   2
#
#    parameters_value
# 0          0.011765
# 1          0.010000
# 2          0.014286
# 3          0.016667
# 4          0.025000

# %%
merging_matching = pd.merge(matchups_2016, parameter_match_ups, how='left', left_on=['player_1','player_2'], right_on = ['player_1','player_2'])

# %%
merging_matching.head()
# Out:
#   surface  player_1_win             player_1                     player_2  \
# 0    Clay             0  Alexandr Dolgopolov                 David Ferrer
# 1    Clay             1  Alexandr Dolgopolov             Andrey Kuznetsov
# 2    Clay             0    Fernando Verdasco                 David Ferrer
# 3    Clay             1     Andrey Kuznetsov  Diego Sebastian Schwartzman
# 4    Clay             0      Karen Khachanov          Alexandr Dolgopolov
#
#   Player_1_hand Player_2_hand   ace_pct    df_pct  first_serve_pct  \
# 0             R             R -0.074903  0.004973        -0.031930
# 1             R             R  0.091328 -0.002168         0.026147
# 2             L             R -0.057606  0.002780        -0.091490
# 3             R             R -0.010170 -0.002854        -0.011382
# 4             R             R -0.082056  0.004406        -0.031315
#
#    broken_pct        ...         player_hand_win_pct  \
# 0    0.115524        ...                   -0.272727
# 1   -0.069470        ...                    0.098059
# 2    0.178378        ...                   -0.204545
# 3    0.040271        ...                   -0.198179
# 4    0.109171        ...                   -0.216634
#
#                                      player_1_losses  \
# 0  ['Grigor Dimitrov', 'Roger Federer', 'Diego Se...
# 1  ['Grigor Dimitrov', 'Roger Federer', 'Diego Se...
# 2  ['Novak Djokovic', 'Dudi Sela', 'Renzo Olivo',...
# 3  ['Rafael Nadal', 'Gael Monfils', 'Viktor Troic...
# 4  ['Gilles Muller', 'Alexandr Dolgopolov', 'Albe...
#
#                                        player_1_wins  \
# 0  ['Alexander Sarkissian', 'Thomaz Bellucci', 'R...
# 1  ['Alexander Sarkissian', 'Thomaz Bellucci', 'R...
# 2  ['Malek Jaziri', 'Rafael Nadal', 'Martin Kliza...
# 3  ['Ricardas Berankis', 'Marsel Ilhan', 'Ryan Ha...
# 4  ['Roberto Bautista Agut', 'Aljaz Bedene', 'Alj...
#
#                                      player_2_losses  \
# 0  ['Illya Marchenko', 'Jack Sock', 'Andy Murray'...
# 1  ['Rafael Nadal', 'Gael Monfils', 'Viktor Troic...
# 2  ['Illya Marchenko', 'Jack Sock', 'Andy Murray'...
# 3  ['John Millman', 'Paolo Lorenzi', 'Dominic Thi...
# 4  ['Grigor Dimitrov', 'Roger Federer', 'Diego Se...
#
#                                        player_2_wins  \
# 0  ['Lukas Rosol', 'Matthew Barton', 'Peter Gojow...
# 1  ['Ricardas Berankis', 'Marsel Ilhan', 'Ryan Ha...
# 2  ['Lukas Rosol', 'Matthew Barton', 'Peter Gojow...
# 3  ['Alexandr Dolgopolov', 'Joao Souza', 'Horacio...
# 4  ['Alexander Sarkissian', 'Thomaz Bellucci', 'R...
#
#   player_1_losses_in_player_2_wins player_2_losses_in_player_1_wins  \
# 0                              3.0                              8.0
# 1                              3.0                              5.0
# 2                              8.0                              9.0
# 3                              6.0                              2.0
# 4                              6.0                              3.0
#
#   player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                            6.0                                 8.0
# 1                            8.0                                10.0
# 2                           10.0                                 8.0
# 3                            3.0                                 8.0
# 4                            6.0                                 8.0
#
#    parameters_value
# 0          0.027273
# 1          0.037500
# 2          0.047059
# 3          0.075000
# 4          0.066667
#
# [5 rows x 23 columns]

# %%
merging_matching = merging_matching.dropna(axis=0,how="any")

# %%
del merging_matching["player_1_losses"]
del merging_matching["player_1_wins"]
del merging_matching["player_2_losses"]
del merging_matching["player_2_wins"]
del merging_matching["player_1_losses_in_player_2_wins"]
del merging_matching["player_1_losses_in_player_2_losses"]
del merging_matching["player_1_wins_in_player_2_wins"]
del merging_matching["player_2_losses_in_player_1_wins"]

# %%
merging_matching.head()
# Out:
#   surface  player_1_win             player_1                     player_2  \
# 0    Clay             0  Alexandr Dolgopolov                 David Ferrer
# 1    Clay             1  Alexandr Dolgopolov             Andrey Kuznetsov
# 2    Clay             0    Fernando Verdasco                 David Ferrer
# 3    Clay             1     Andrey Kuznetsov  Diego Sebastian Schwartzman
# 4    Clay             0      Karen Khachanov          Alexandr Dolgopolov
#
#   Player_1_hand Player_2_hand   ace_pct    df_pct  first_serve_pct  \
# 0             R             R -0.074903  0.004973        -0.031930
# 1             R             R  0.091328 -0.002168         0.026147
# 2             L             R -0.057606  0.002780        -0.091490
# 3             R             R -0.010170 -0.002854        -0.011382
# 4             R             R -0.082056  0.004406        -0.031315
#
#    broken_pct  breaking_pct  break_conversion_pct  surface_win_pct  \
# 0    0.115524      0.012928              0.006386        -0.201136
# 1   -0.069470     -0.046227             -0.011295         0.069192
# 2    0.178378     -0.059082             -0.089444        -0.162500
# 3    0.040271     -0.022511              0.011092        -0.182249
# 4    0.109171      0.013037              0.003506        -0.370779
#
#    player_hand_win_pct  parameters_value
# 0            -0.272727          0.027273
# 1             0.098059          0.037500
# 2            -0.204545          0.047059
# 3            -0.198179          0.075000
# 4            -0.216634          0.066667

# %%
len(merging_matching)
# Out:
# 2186

# %%
#parameter_match_ups[parameter_match_ups.player_1==matchups_2016.player_1 and parameter_match_ups.player_2==matchups_2016.player_2]

# %%
#parameter_match_ups.player_1==matchups_2016.player_1

# %%
merging_matching.to_csv("merging_matching_first_inputs_3.csv")

# %%
##if you ran the previous code, no need to run this
merging_matching = pd.read_csv("merging_matching_first_inputs.csv")
del merging_matching["Unnamed: 0"]
merging_matching.head()

# %%
merging_matching.head()

# %%
X = merging_matching.drop(["player_1_win", "player_1", "player_2", "surface", "Player_1_hand", "Player_2_hand"], axis=1)
y = merging_matching["player_1_win"]
print(X.shape, y.shape)
# Out:
# (2186, 9) (2186,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
y_test_indexes = list(y_test.index)

# %%
for i in range(127):
    y_test = y_test.drop([y_test_indexes[i]])

len(y_test)
# Out:
# 420

# %%
##wimbledon is sure to be in the tested

y_test = pd.concat([y_test,wimbledon_matches["player_1_win"]])

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.5802318486882245
# Testing Data Score: 0.5393053016453382

# %%
predictions_prob = classifier.predict_proba(X_test)
predictions1 = classifier.predict(X_test)

# %%
clean_data = [[item for item in row] for row in predictions_prob]

# %%
player_prob = pd.DataFrame(clean_data, columns=["player_1_prob","player_2_prob"])

# %%
player_prob.head()
# Out:
#    player_1_prob  player_2_prob
# 0       0.563553       0.436447
# 1       0.428455       0.571545
# 2       0.471057       0.528943
# 3       0.526509       0.473491
# 4       0.470642       0.529358

# %%
#pd.DataFrame({"Prediction": predictions1, "Actual": y_test}).reset_index(drop=True).head()

# %%
predictions_dataframe = X_test

# %%
player_prob['index'] = predictions_dataframe.index
player_prob = player_prob.set_index('index')

# %%
player_prob.head()
# Out:
#        player_1_prob  player_2_prob
# index
# 1501        0.563553       0.436447
# 480         0.428455       0.571545
# 169         0.471057       0.528943
# 1309        0.526509       0.473491
# 1704        0.470642       0.529358

# %%
player_prob_merge = predictions_dataframe.join(player_prob, how = "inner")

# %%
player_prob_merge.head()
# Out:
#         ace_pct    df_pct  first_serve_pct  broken_pct  breaking_pct  \
# index
# 1501   0.016428  0.006237         0.006652   -0.014253     -0.084154
# 480   -0.030632  0.012536        -0.051592    0.162988      0.109244
# 169    0.026978 -0.004342         0.054721   -0.113987      0.006266
# 1309   0.062222  0.001493         0.061767   -0.116923     -0.055126
# 1704   0.038077 -0.008546         0.072520    0.152632     -0.022511
#
#        break_conversion_pct  surface_win_pct  player_hand_win_pct  \
# index
# 1501              -0.066359        -0.156126            -0.234525
# 480                0.032160         0.257576             0.012903
# 169               -0.044380         0.233155             0.276316
# 1309              -0.013364        -0.094444            -0.008333
# 1704              -0.094093        -0.187500            -0.258065
#
#        parameters_value  player_1_prob  player_2_prob
# index
# 1501           0.072727       0.563553       0.436447
# 480            0.077778       0.428455       0.571545
# 169            0.066667       0.471057       0.528943
# 1309           0.000000       0.526509       0.473491
# 1704           0.000000       0.470642       0.529358

# %%
player_prob_merge["Prediction"] = predictions1

# %%
player_prob_merge["Actual"] = y_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-4cb83d096d4b> in <module>()
# ----> 1 player_prob_merge["Actual"] = y_test
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2545
#    2546         if isinstance(value, Series):
# -> 2547             value = reindexer(value)
#    2548
#    2549         elif isinstance(value, DataFrame):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    2537                     # duplicate axis
#    2538                     if not value.index.is_unique:
# -> 2539                         raise e
#    2540
#    2541                     # other
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    2532                 # GH 4107
#    2533                 try:
# -> 2534                     value = value.reindex(self.index)._values
#    2535                 except Exception as e:
#    2536
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    2424     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    2425     def reindex(self, index=None, **kwargs):
# -> 2426         return super(Series, self).reindex(index=index, **kwargs)
#    2427
#    2428     @Appender(generic._shared_docs['fillna'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    2513         # perform the reindex on the axes
#    2514         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 2515                                   fill_value, copy).__finalize__(self)
#    2516
#    2517     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2531             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    2532                                              fill_value=fill_value,
# -> 2533                                              copy=copy, allow_dups=False)
#    2534
#    2535         return obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    2625                                                 fill_value=fill_value,
#    2626                                                 allow_dups=allow_dups,
# -> 2627                                                 copy=copy)
#    2628
#    2629         if copy and new_data is self._data:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3884         # some axes don't allow reindexing with dups
#    3885         if not allow_dups:
# -> 3886             self.axes[axis]._can_reindex(indexer)
#    3887
#    3888         if axis >= self.ndim:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    2834         # trying to reindex on an axis with duplicates
#    2835         if not self.is_unique and len(indexer):
# -> 2836             raise ValueError("cannot reindex from a duplicate axis")
#    2837
#    2838     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
player_prob_merge.head(5)
# Out:
#         ace_pct    df_pct  first_serve_pct  broken_pct  breaking_pct  \
# index
# 1501   0.016428  0.006237         0.006652   -0.014253     -0.084154
# 480   -0.030632  0.012536        -0.051592    0.162988      0.109244
# 169    0.026978 -0.004342         0.054721   -0.113987      0.006266
# 1309   0.062222  0.001493         0.061767   -0.116923     -0.055126
# 1704   0.038077 -0.008546         0.072520    0.152632     -0.022511
#
#        break_conversion_pct  surface_win_pct  player_hand_win_pct  \
# index
# 1501              -0.066359        -0.156126            -0.234525
# 480                0.032160         0.257576             0.012903
# 169               -0.044380         0.233155             0.276316
# 1309              -0.013364        -0.094444            -0.008333
# 1704              -0.094093        -0.187500            -0.258065
#
#        parameters_value  player_1_prob  player_2_prob  Prediction
# index
# 1501           0.072727       0.563553       0.436447           0
# 480            0.077778       0.428455       0.571545           1
# 169            0.066667       0.471057       0.528943           1
# 1309           0.000000       0.526509       0.473491           0
# 1704           0.000000       0.470642       0.529358           1

# %%
players = merging_matching[["player_1", "player_2"]]

# %%
players.head()

# %%
final_result_1 = players.join(player_prob_merge, how  ="inner")

# %%
final_result_1 = final_result_1.rename(index=str, columns={"player_1_prob": "player_2_prob","player_2_prob":"player_1_prob"})

# %%
final_result_1.to_csv("results_predicting_all_2017.csv")

# %%
final_result_1
