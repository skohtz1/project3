# %%
import pandas as pd
import numpy as np
from itertools import combinations, product
from ast import literal_eval

# %%
##atp_2015 is now atp_2017 but the variable name has not changed
##atp_2015 is now atp_2017 but the variable name has not changed
##atp_2015 is now atp_2017 but the variable name has not changed

# %%
atp_2015 = pd.read_csv("atp_2017.csv")

# %%
frames = [atp_2015["winner_name"],atp_2015["loser_name"]]

# %%
results = pd.concat(frames)

# %%
players = results.unique()

# %%
atp_2015_win_lose = atp_2015[['winner_name','loser_name']]

# %%
atp_2015_win_lose = atp_2015_win_lose.dropna(axis=0,how="any")

# %%
atp_2015_opponents_win = atp_2015_win_lose.groupby("winner_name")["loser_name"].apply(list)
atp_2015_opponents_loss = atp_2015_win_lose.groupby("loser_name")["winner_name"].apply(list)
atp_2015_opponents_loss = pd.DataFrame(atp_2015_opponents_loss)
atp_2015_opponents_loss = atp_2015_opponents_loss.reset_index()
atp_2015_opponents_win = pd.DataFrame(atp_2015_opponents_win)
atp_2015_opponents_win = atp_2015_opponents_win.reset_index()
atp_2015_opponents_win = atp_2015_opponents_win.rename(index=str, columns={"winner_name": "name","loser_name":"wins"})
atp_2015_opponents_loss = atp_2015_opponents_loss.rename(index=str, columns={"loser_name": "name","winner_name":"losses"})

# %%
merge_table = pd.merge(atp_2015_opponents_loss, atp_2015_opponents_win, on="name", how="outer")
merge_table.to_csv("merge_table_4.csv")

# %%
##i manually changed the csv..dont judge :P
##the players with no wins need to win ["bye"]

# %%
merge_table = pd.read_csv("merge_table_3.csv")
del merge_table["Unnamed: 0"]
merge_table.head()
# Out:
#                    name                                             losses  \
# 0       Abdullah Maqdas  ['Jirat Navasirisomboon', 'Wishaya Trongcharoe...
# 1           Adam Hornby                      ['Christopher Diaz Figueroa']
# 2         Adam Pavlasek  ['Jeremy Chardy', 'Nikoloz Basilashvili', 'Rya...
# 3  Aditya Hari Sasongko                                 ['Ruben Gonzales']
# 4      Adrian Mannarino  ['Nicolas Mahut', 'Samuel Groth', 'Roberto Bau...
#
#                                                 wins
# 0                                            ['Bye']
# 1                                            ['Bye']
# 2  ['Roberto Carballes Baena', 'Marcel Granollers...
# 3                                            ['Bye']
# 4  ['Marius Copil', 'Evgeny Donskoy', 'Tatsuma It...

# %%
##fun fact: the lists are strings and not lists! this changes it back (necessary for later stuff)
merge_table.loc[:,'losses'] = merge_table.loc[:,'losses'].apply(lambda x: literal_eval(x))
merge_table.loc[:,'wins'] = merge_table.loc[:,'wins'].apply(lambda x: literal_eval(x))

# %%
merge_table.head()
# Out:
#                    name                                             losses  \
# 0       Abdullah Maqdas  [Jirat Navasirisomboon, Wishaya Trongcharoench...
# 1           Adam Hornby                        [Christopher Diaz Figueroa]
# 2         Adam Pavlasek  [Jeremy Chardy, Nikoloz Basilashvili, Ryan Har...
# 3  Aditya Hari Sasongko                                   [Ruben Gonzales]
# 4      Adrian Mannarino  [Nicolas Mahut, Samuel Groth, Roberto Bautista...
#
#                                                 wins
# 0                                              [Bye]
# 1                                              [Bye]
# 2  [Roberto Carballes Baena, Marcel Granollers, M...
# 3                                              [Bye]
# 4  [Marius Copil, Evgeny Donskoy, Tatsuma Ito, Ma...

# %%
prod = list(product(atp_2015_win_lose['loser_name'].unique(), atp_2015_win_lose['loser_name'].unique()))

# %%
len(prod)
# Out:
# 173056

# %%
all_possible_matches = pd.DataFrame(prod)

# %%
all_possible_matches.head()
# Out:
#                0                   1
# 0  Kei Nishikori       Kei Nishikori
# 1  Kei Nishikori        Milos Raonic
# 2  Kei Nishikori  Stanislas Wawrinka
# 3  Kei Nishikori        Rafael Nadal
# 4  Kei Nishikori       Dominic Thiem

# %%
all_possible_matches = all_possible_matches.rename(index=str, columns={0: "player_1",1:"player_2"})

# %%
all_possible_matches = all_possible_matches.drop(all_possible_matches[all_possible_matches.player_1 == all_possible_matches.player_2].index)

# %%
all_possible_matches.head()
# Out:
#         player_1            player_2
# 1  Kei Nishikori        Milos Raonic
# 2  Kei Nishikori  Stanislas Wawrinka
# 3  Kei Nishikori        Rafael Nadal
# 4  Kei Nishikori       Dominic Thiem
# 5  Kei Nishikori     Jordan Thompson

# %%
# all_possible_matches["player_1_wins"] = merge_table.loc([merge_table['name'] == all_possible_matches["player_1"], ['wins']])

# %%
merge_table_test = merge_table.rename(index=str, columns = {"name":"player_1"})

# %%
merge_table_test.head()
# Out:
#                player_1                                             losses  \
# 0       Abdullah Maqdas  [Jirat Navasirisomboon, Wishaya Trongcharoench...
# 1           Adam Hornby                        [Christopher Diaz Figueroa]
# 2         Adam Pavlasek  [Jeremy Chardy, Nikoloz Basilashvili, Ryan Har...
# 3  Aditya Hari Sasongko                                   [Ruben Gonzales]
# 4      Adrian Mannarino  [Nicolas Mahut, Samuel Groth, Roberto Bautista...
#
#                                                 wins
# 0                                              [Bye]
# 1                                              [Bye]
# 2  [Roberto Carballes Baena, Marcel Granollers, M...
# 3                                              [Bye]
# 4  [Marius Copil, Evgeny Donskoy, Tatsuma Ito, Ma...

# %%
matching_merge = pd.merge(all_possible_matches,merge_table_test, on = "player_1", how = "outer")

# %%
matching_merge.head()
# Out:
#         player_1            player_2  \
# 0  Kei Nishikori        Milos Raonic
# 1  Kei Nishikori  Stanislas Wawrinka
# 2  Kei Nishikori        Rafael Nadal
# 3  Kei Nishikori       Dominic Thiem
# 4  Kei Nishikori     Jordan Thompson
#
#                                               losses  \
# 0  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 1  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 2  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 3  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 4  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
#
#                                                 wins
# 0  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 1  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 2  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 3  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 4  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...

# %%
matching_merge = matching_merge.rename(index = str, columns = {"losses": "player_1_losses","wins": "player_1_wins"})

# %%
matching_merge.head()
# Out:
#         player_1            player_2  \
# 0  Kei Nishikori        Milos Raonic
# 1  Kei Nishikori  Stanislas Wawrinka
# 2  Kei Nishikori        Rafael Nadal
# 3  Kei Nishikori       Dominic Thiem
# 4  Kei Nishikori     Jordan Thompson
#
#                                      player_1_losses  \
# 0  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 1  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 2  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 3  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 4  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
#
#                                        player_1_wins
# 0  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 1  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 2  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 3  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 4  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...

# %%
merge_table_test = merge_table.rename(index=str, columns = {"name":"player_2"})

# %%
merge_table_test.head()
# Out:
#                player_2                                             losses  \
# 0       Abdullah Maqdas  [Jirat Navasirisomboon, Wishaya Trongcharoench...
# 1           Adam Hornby                        [Christopher Diaz Figueroa]
# 2         Adam Pavlasek  [Jeremy Chardy, Nikoloz Basilashvili, Ryan Har...
# 3  Aditya Hari Sasongko                                   [Ruben Gonzales]
# 4      Adrian Mannarino  [Nicolas Mahut, Samuel Groth, Roberto Bautista...
#
#                                                 wins
# 0                                              [Bye]
# 1                                              [Bye]
# 2  [Roberto Carballes Baena, Marcel Granollers, M...
# 3                                              [Bye]
# 4  [Marius Copil, Evgeny Donskoy, Tatsuma Ito, Ma...

# %%
matching_merge_1 = pd.merge(all_possible_matches,merge_table_test, on = "player_2", how = "outer")

# %%
matching_merge_1 = matching_merge_1.rename(index = str, columns = {"losses": "player_2_losses","wins": "player_2_wins"})

# %%
matching_merge_1.head()
# Out:
#              player_1      player_2  \
# 0       Kei Nishikori  Milos Raonic
# 1  Stanislas Wawrinka  Milos Raonic
# 2        Rafael Nadal  Milos Raonic
# 3       Dominic Thiem  Milos Raonic
# 4     Jordan Thompson  Milos Raonic
#
#                                      player_2_losses  \
# 0  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 1  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 2  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 3  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 4  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
#
#                                        player_2_wins
# 0  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 1  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 2  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 3  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 4  [Roger Federer, Bernard Tomic, Lucas Pouille, ...

# %%
attempt_merge = pd.merge(matching_merge, matching_merge_1,  how='left', left_on=['player_1','player_2'], right_on = ['player_1','player_2'])

# %%
##i dont know why there are NAs

attempt_merge1 = attempt_merge.dropna(axis=0,how="any")

# %%
# del attempt_merge1["player_1_losses_in_player_2_wins"]
# del attempt_merge1["player_2_losses_in_player_1_wins"]
# del attempt_merge1["player_1_wins_in_player_2_wins"]
# del attempt_merge1["player_1_losses_in_player_2_losses"]

# %%
attempt_merge1.head()
# Out:
#         player_1            player_2  \
# 0  Kei Nishikori        Milos Raonic
# 1  Kei Nishikori  Stanislas Wawrinka
# 2  Kei Nishikori        Rafael Nadal
# 3  Kei Nishikori       Dominic Thiem
# 4  Kei Nishikori     Jordan Thompson
#
#                                      player_1_losses  \
# 0  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 1  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 2  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 3  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 4  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
#
#                                        player_1_wins  \
# 0  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 1  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 2  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 3  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 4  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
#
#                                      player_2_losses  \
# 0  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 1  [Milos Raonic, Benoit Paire, David Goffin, And...
# 2  [Novak Djokovic, Fernando Verdasco, Dominic Th...
# 3  [Roger Federer, Gilles Muller, David Goffin, G...
# 4  [Bernard Tomic, Thomaz Bellucci, Ivo Karlovic,...
#
#                                        player_2_wins
# 0  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 1  [Borna Coric, Benoit Paire, Guillermo Garcia L...
# 2  [Illya Marchenko, Andrey Kuznetsov, Robin Haas...
# 3  [Marin Cilic, Denis Kudla, James Duckworth, Le...
# 4  [Martin Klizan, Laslo Djere, Victor Estrella, ...

# %%
attempt_merge1['player_1_losses_in_player_2_wins'] = [(list(set(a).intersection(set(b)))) for a, b in zip(attempt_merge1.player_1_losses,attempt_merge1.player_2_wins)]
attempt_merge1['player_2_losses_in_player_1_wins'] = [list(set(a).intersection(set(b))) for a, b in zip(attempt_merge1.player_2_losses,attempt_merge1.player_1_wins)]
attempt_merge1['player_1_wins_in_player_2_wins'] = [list(set(a).intersection(set(b))) for a, b in zip(attempt_merge1.player_1_wins,attempt_merge1.player_2_wins)]
attempt_merge1['player_1_losses_in_player_2_losses'] = [list(set(a).intersection(set(b))) for a, b in zip(attempt_merge1.player_1_losses,attempt_merge1.player_2_losses)]
# Out:
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
attempt_merge1.head()
# Out:
#         player_1            player_2  \
# 0  Kei Nishikori        Milos Raonic
# 1  Kei Nishikori  Stanislas Wawrinka
# 2  Kei Nishikori        Rafael Nadal
# 3  Kei Nishikori       Dominic Thiem
# 4  Kei Nishikori     Jordan Thompson
#
#                                      player_1_losses  \
# 0  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 1  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 2  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 3  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 4  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
#
#                                        player_1_wins  \
# 0  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 1  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 2  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 3  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 4  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
#
#                                      player_2_losses  \
# 0  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 1  [Milos Raonic, Benoit Paire, David Goffin, And...
# 2  [Novak Djokovic, Fernando Verdasco, Dominic Th...
# 3  [Roger Federer, Gilles Muller, David Goffin, G...
# 4  [Bernard Tomic, Thomaz Bellucci, Ivo Karlovic,...
#
#                                        player_2_wins  \
# 0  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 1  [Borna Coric, Benoit Paire, Guillermo Garcia L...
# 2  [Illya Marchenko, Andrey Kuznetsov, Robin Haas...
# 3  [Marin Cilic, Denis Kudla, James Duckworth, Le...
# 4  [Martin Klizan, Laslo Djere, Victor Estrella, ...
#
#                     player_1_losses_in_player_2_wins  \
# 0  [Roger Federer, Jack Sock, Rafael Nadal, Stani...
# 1  [Marin Cilic, Jack Sock, Sam Querrey, Andy Mur...
# 2  [Marin Cilic, Jack Sock, Stanislas Wawrinka, G...
# 3  [Roger Federer, Marin Cilic, Jack Sock, Rafael...
# 4               [Joao Sousa, Andy Murray, Jack Sock]
#
#                     player_2_losses_in_player_1_wins  \
# 0  [Gael Monfils, Thanasi Kokkinakis, Mikhail You...
# 1  [John Isner, Rafael Nadal, Andrey Kuznetsov, G...
# 2  [Dominic Thiem, Grigor Dimitrov, Lucas Pouille...
# 3  [Daniel Evans, Jo Wilfried Tsonga, Rafael Nada...
# 4  [Dominic Thiem, John Isner, Benjamin Becker, K...
#
#                       player_1_wins_in_player_2_wins  \
# 0  [Viktor Troicki, Alexandr Dolgopolov, Jared Do...
# 1  [Jeremy Chardy, Taylor Harry Fritz, Viktor Tro...
# 2  [Joao Sousa, Alexandr Dolgopolov, Fabio Fognin...
# 3  [Jeremy Chardy, David Ferrer, Dusan Lajovic, J...
# 4  [Joao Sousa, Benoit Paire, David Ferrer, Andy ...
#
#                   player_1_losses_in_player_2_losses
# 0  [Roger Federer, Marin Cilic, Jack Sock, Rafael...
# 1  [Roger Federer, Rafael Nadal, Grigor Dimitrov,...
# 2  [Roger Federer, Grigor Dimitrov, Andy Murray, ...
# 3  [Roger Federer, Jack Sock, Rafael Nadal, Stani...
# 4  [Sam Querrey, Bernard Tomic, Karen Khachanov, ...

# %%
#[list(len(a+b)) for a, b in zip(attempt_merge1.player_1_losses_in_player_2_wins,attempt_merge1.player_2_losses_in_player_1_wins)]

# %%
##for the numbers
attempt_merge1['player_1_losses_in_player_2_wins'] = [len((list(set(a).intersection(set(b))))) for a, b in zip(attempt_merge1.player_1_losses,attempt_merge1.player_2_wins)]
attempt_merge1['player_2_losses_in_player_1_wins'] = [len(list(set(a).intersection(set(b)))) for a, b in zip(attempt_merge1.player_2_losses,attempt_merge1.player_1_wins)]
attempt_merge1['player_1_wins_in_player_2_wins'] = [len(list(set(a).intersection(set(b)))) for a, b in zip(attempt_merge1.player_1_wins,attempt_merge1.player_2_wins)]
attempt_merge1['player_1_losses_in_player_2_losses'] = [len(list(set(a).intersection(set(b)))) for a, b in zip(attempt_merge1.player_1_losses,attempt_merge1.player_2_losses)]
# Out:
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
attempt_merge1.head()
# Out:
#         player_1            player_2  \
# 0  Kei Nishikori        Milos Raonic
# 1  Kei Nishikori  Stanislas Wawrinka
# 2  Kei Nishikori        Rafael Nadal
# 3  Kei Nishikori       Dominic Thiem
# 4  Kei Nishikori     Jordan Thompson
#
#                                      player_1_losses  \
# 0  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 1  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 2  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 3  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 4  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
#
#                                        player_1_wins  \
# 0  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 1  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 2  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 3  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 4  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
#
#                                      player_2_losses  \
# 0  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 1  [Milos Raonic, Benoit Paire, David Goffin, And...
# 2  [Novak Djokovic, Fernando Verdasco, Dominic Th...
# 3  [Roger Federer, Gilles Muller, David Goffin, G...
# 4  [Bernard Tomic, Thomaz Bellucci, Ivo Karlovic,...
#
#                                        player_2_wins  \
# 0  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 1  [Borna Coric, Benoit Paire, Guillermo Garcia L...
# 2  [Illya Marchenko, Andrey Kuznetsov, Robin Haas...
# 3  [Marin Cilic, Denis Kudla, James Duckworth, Le...
# 4  [Martin Klizan, Laslo Djere, Victor Estrella, ...
#
#    player_1_losses_in_player_2_wins  player_2_losses_in_player_1_wins  \
# 0                                11                                 9
# 1                                11                                 9
# 2                                14                                 9
# 3                                12                                14
# 4                                 3                                13
#
#    player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses
# 0                              22                                   7
# 1                              27                                   6
# 2                              27                                   6
# 3                              24                                   9
# 4                               4                                   6

# %%
attempt_merge1["parameters_value"] = [(a/(a+b))*(1/10) for a, b in zip(attempt_merge1.player_1_losses_in_player_2_wins,attempt_merge1.player_2_losses_in_player_1_wins)]
# Out:
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in longlong_scalars
#   """Entry point for launching an IPython kernel.
# C:\Users\gizmo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
attempt_merge1.head()
# Out:
#         player_1            player_2  \
# 0  Kei Nishikori        Milos Raonic
# 1  Kei Nishikori  Stanislas Wawrinka
# 2  Kei Nishikori        Rafael Nadal
# 3  Kei Nishikori       Dominic Thiem
# 4  Kei Nishikori     Jordan Thompson
#
#                                      player_1_losses  \
# 0  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 1  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 2  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 3  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 4  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
#
#                                        player_1_wins  \
# 0  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 1  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 2  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 3  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 4  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
#
#                                      player_2_losses  \
# 0  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 1  [Milos Raonic, Benoit Paire, David Goffin, And...
# 2  [Novak Djokovic, Fernando Verdasco, Dominic Th...
# 3  [Roger Federer, Gilles Muller, David Goffin, G...
# 4  [Bernard Tomic, Thomaz Bellucci, Ivo Karlovic,...
#
#                                        player_2_wins  \
# 0  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 1  [Borna Coric, Benoit Paire, Guillermo Garcia L...
# 2  [Illya Marchenko, Andrey Kuznetsov, Robin Haas...
# 3  [Marin Cilic, Denis Kudla, James Duckworth, Le...
# 4  [Martin Klizan, Laslo Djere, Victor Estrella, ...
#
#    player_1_losses_in_player_2_wins  player_2_losses_in_player_1_wins  \
# 0                                11                                 9
# 1                                11                                 9
# 2                                14                                 9
# 3                                12                                14
# 4                                 3                                13
#
#    player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                              22                                   7
# 1                              27                                   6
# 2                              27                                   6
# 3                              24                                   9
# 4                               4                                   6
#
#    parameters_value
# 0          0.055000
# 1          0.055000
# 2          0.060870
# 3          0.046154
# 4          0.018750

# %%
final_merge_thing_help = attempt_merge1.fillna(0)

# %%
final_merge_thing_help.to_csv("matchups_parameters_4.csv")

# %%
final_merge_thing_help.head()
# Out:
#         player_1            player_2  \
# 0  Kei Nishikori        Milos Raonic
# 1  Kei Nishikori  Stanislas Wawrinka
# 2  Kei Nishikori        Rafael Nadal
# 3  Kei Nishikori       Dominic Thiem
# 4  Kei Nishikori     Jordan Thompson
#
#                                      player_1_losses  \
# 0  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 1  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 2  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 3  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
# 4  [Bernard Tomic, Novak Djokovic, Sam Querrey, R...
#
#                                        player_1_wins  \
# 0  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 1  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 2  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 3  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
# 4  [Mikhail Kukushkin, Philipp Kohlschreiber, Aus...
#
#                                      player_2_losses  \
# 0  [Andy Murray, Novak Djokovic, Nick Kyrgios, An...
# 1  [Milos Raonic, Benoit Paire, David Goffin, And...
# 2  [Novak Djokovic, Fernando Verdasco, Dominic Th...
# 3  [Roger Federer, Gilles Muller, David Goffin, G...
# 4  [Bernard Tomic, Thomaz Bellucci, Ivo Karlovic,...
#
#                                        player_2_wins  \
# 0  [Roger Federer, Bernard Tomic, Lucas Pouille, ...
# 1  [Borna Coric, Benoit Paire, Guillermo Garcia L...
# 2  [Illya Marchenko, Andrey Kuznetsov, Robin Haas...
# 3  [Marin Cilic, Denis Kudla, James Duckworth, Le...
# 4  [Martin Klizan, Laslo Djere, Victor Estrella, ...
#
#    player_1_losses_in_player_2_wins  player_2_losses_in_player_1_wins  \
# 0                                11                                 9
# 1                                11                                 9
# 2                                14                                 9
# 3                                12                                14
# 4                                 3                                13
#
#    player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                              22                                   7
# 1                              27                                   6
# 2                              27                                   6
# 3                              24                                   9
# 4                               4                                   6
#
#    parameters_value
# 0          0.055000
# 1          0.055000
# 2          0.060870
# 3          0.046154
# 4          0.018750
