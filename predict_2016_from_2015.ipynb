# %%
import pandas as pd
import numpy as np

# %%
atp_2015 = pd.read_csv("atp_2015.csv")
atp_2015.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2015-329        Tokyo    Hard       32.0             A    20151005.0
# 1   2015-329        Tokyo    Hard       32.0             A    20151005.0
# 2   2015-329        Tokyo    Hard       32.0             A    20151005.0
# 3   2015-329        Tokyo    Hard       32.0             A    20151005.0
# 4   2015-329        Tokyo    Hard       32.0             A    20151005.0
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 0        1.0   104527.0          1.0          NaN    ...          1.0   2.0
# 1        2.0   105147.0          NaN           WC    ...         14.0   1.0
# 2        3.0   105572.0          NaN            Q    ...          7.0  15.0
# 3        4.0   105311.0          NaN          NaN    ...          6.0   9.0
# 4        5.0   104468.0          3.0          NaN    ...          6.0   0.0
#
#    l_df l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved l_bpFaced
# 0   2.0   71.0     46.0      33.0      10.0     10.0        2.0       5.0
# 1   4.0   96.0     52.0      25.0      23.0     13.0       12.0      19.0
# 2   7.0  128.0     74.0      60.0      27.0     18.0        9.0      11.0
# 3   5.0   85.0     42.0      27.0      21.0     13.0        4.0       8.0
# 4   5.0   61.0     33.0      24.0      10.0     10.0        1.0       5.0
#
# [5 rows x 49 columns]

# %%
atp_2015.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
surface_grass = atp_2015['surface'] == "Grass"
surface_clay = atp_2015["surface"]=="Clay"
surface_hard = atp_2015["surface"]=="Hard"
surface_clay_df = atp_2015[surface_clay]
surface_hard_df = atp_2015[surface_hard]
surface_df = atp_2015[surface_grass]

# %%
player_win_right = atp_2015["winner_hand"] == "R"
player_winners_right_df = atp_2015[player_win_right]
player_loser_right = atp_2015["loser_hand"] =="R"
player_loser_right_df = atp_2015[player_loser_right]
player_win_left = atp_2015["winner_hand"] == "L"
player_winner_left_df = atp_2015[player_win_left]
player_loser_left = atp_2015["loser_hand"] =="L"
player_loser_left_df = atp_2015[player_loser_left]

# %%
winners_right = pd.DataFrame(player_loser_right_df["winner_name"].value_counts())
losers_right = pd.DataFrame(player_winners_right_df["loser_name"].value_counts())

# %%
winners_left = pd.DataFrame(player_loser_left_df["winner_name"].value_counts())
losers_left = pd.DataFrame(player_winner_left_df["loser_name"].value_counts())

# %%
combined_RL1 = winners_left.join(losers_left, how = "outer")
combined_RL_Left = combined_RL1.fillna(0)
combined_RL_Left = combined_RL_Left.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
combined_RL_Left["Left_hand_win_pct"] = combined_RL_Left["wins"]/(combined_RL_Left["wins"]+combined_RL_Left["losses"])
combined_RL_Left.head()
# Out:
#                           wins  losses  Left_hand_win_pct
# Adrian Mannarino           7.0     4.0           0.636364
# Adrian Menendez Maceiras   0.0     1.0           0.000000
# Albert Montanes            1.0     2.0           0.333333
# Albert Ramos               1.0     2.0           0.333333
# Alejandro Falla            2.0     1.0           0.666667

# %%
combined_RL = winners_right.join(losers_right,how = "outer")
combined_RL_Right = combined_RL.fillna(0)
combined_RL_Right= combined_RL_Right.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
combined_RL_Right["right_hand_win_pct"] = combined_RL_Right["wins"]/(combined_RL_Right["wins"]+combined_RL_Right["losses"])
combined_RL_Right.head()
# Out:
#                           wins  losses  right_hand_win_pct
# Adrian Mannarino          19.0    26.0            0.422222
# Adrian Menendez Maceiras   1.0     3.0            0.250000
# Adrien Bossel              0.0     1.0            0.000000
# Albert Montanes            6.0     6.0            0.500000
# Albert Ramos              14.0    20.0            0.411765

# %%
# combined_RL_Right.head()

# %%
del combined_RL_Right["wins"]
del combined_RL_Left["wins"]
del combined_RL_Right["losses"]
del combined_RL_Left["losses"]

# %%
surface_df.head()
# Out:
#     tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 316   2015-540    Wimbledon   Grass      128.0             G    20150629.0
# 317   2015-540    Wimbledon   Grass      128.0             G    20150629.0
# 318   2015-540    Wimbledon   Grass      128.0             G    20150629.0
# 319   2015-540    Wimbledon   Grass      128.0             G    20150629.0
# 320   2015-540    Wimbledon   Grass      128.0             G    20150629.0
#
#      match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 316        1.0   104925.0          1.0          NaN    ...          9.0   6.0
# 317        2.0   103813.0          NaN          NaN    ...         17.0  12.0
# 318        3.0   105732.0          NaN            Q    ...         15.0   8.0
# 319        4.0   106071.0         27.0          NaN    ...         11.0  25.0
# 320        5.0   104919.0         24.0          NaN    ...          3.0   5.0
#
#      l_df l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved l_bpFaced
# 316   4.0  103.0     66.0      42.0      17.0     15.0        7.0      12.0
# 317   9.0  182.0    100.0      71.0      31.0     27.0       12.0      22.0
# 318   9.0  170.0    105.0      73.0      30.0     25.0       13.0      20.0
# 319  15.0  134.0     80.0      61.0      20.0     21.0        9.0      14.0
# 320   4.0  132.0     81.0      61.0      22.0     17.0        8.0      10.0
#
# [5 rows x 49 columns]

# %%
winners_clay = pd.DataFrame(surface_clay_df["winner_name"].value_counts())
losers_clay = pd.DataFrame(surface_clay_df["loser_name"].value_counts())
winners_hard = pd.DataFrame(surface_hard_df["winner_name"].value_counts())
losers_hard = pd.DataFrame(surface_hard_df["loser_name"].value_counts())
winners_grass = pd.DataFrame(surface_df["winner_name"].value_counts())
losers_grass = pd.DataFrame(surface_df["loser_name"].value_counts())

# %%
winners_clay = winners_clay.reset_index()
losers_clay = losers_clay.reset_index()
winners_hard = winners_hard.reset_index()
losers_hard = losers_hard.reset_index()
winner_grass = winners_grass.reset_index()
losers_grass = losers_grass.reset_index()

# %%
merged_win_lose_clay = pd.merge(winners_clay, losers_clay, how ="outer")
merged_win_lose_hard = pd.merge(winners_hard, losers_hard, how = "outer")
merged_win_lose_grass = pd.merge(winner_grass, losers_grass, how = "outer")

# %%
merged_win_lose_clay = merged_win_lose_clay.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
merged_win_lose_hard = merged_win_lose_hard.rename(index = str, columns = {"winner_name": "wins", "loser_name": "losses"})
merged_win_lose_grass = merged_win_lose_grass.rename(index=str, columns={"winner_name": "wins","loser_name":"losses"})

# %%
merged_win_lose_clay = merged_win_lose_clay.fillna(0)
merged_win_lose_hard  = merged_win_lose_hard.fillna(0)
merged_win_lose_grass = merged_win_lose_grass.fillna(0)

# %%
merged_win_lose_grass["win_pct_grass"] = merged_win_lose_grass["wins"]/(merged_win_lose_grass["wins"]+merged_win_lose_grass["losses"])
merged_win_lose_clay["win_pct_clay"] = merged_win_lose_clay["wins"]/(merged_win_lose_clay["wins"]+merged_win_lose_clay["losses"])
merged_win_lose_hard["win_pct_hard"] = merged_win_lose_hard["wins"]/(merged_win_lose_hard["wins"]+merged_win_lose_hard["losses"])

# %%
merged_win_lose_grass = merged_win_lose_grass.set_index("index")
merged_win_lose_hard = merged_win_lose_hard.set_index("index")
merged_win_lose_clay = merged_win_lose_clay.set_index("index")

# %%
del merged_win_lose_grass["wins"]
del merged_win_lose_grass["losses"]
del merged_win_lose_clay["wins"]
del merged_win_lose_clay["losses"]
del merged_win_lose_hard["wins"]
del merged_win_lose_hard["losses"]

# %%
merged_win_lose_hard.head()
# Out:
#                     win_pct_hard
# index
# Novak Djokovic          0.920635
# Tomas Berdych           0.714286
# Andy Murray             0.760000
# Roger Federer           0.860465
# Stanislas Wawrinka      0.734694

# %%
players = atp_2015["winner_name"]

# %%
players_list = players.unique()

# %%
atp_2015.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
##change players_list to players_list_test for testing
stat_player_df = pd.DataFrame({'name':players_list})

# %%
len(stat_player_df)
# Out:
# 192

# %%
grouped_atp_2015 = atp_2015.groupby(["winner_name"])

# %%
aces = grouped_atp_2015["w_ace"].sum()
service_games = grouped_atp_2015["w_SvGms"].sum()
first_serve_in = grouped_atp_2015["w_1stIn"].sum()
first_serves_won = grouped_atp_2015["w_1stWon"].sum()
doubfts = grouped_atp_2015["w_df"].sum()
total_brk_saved = grouped_atp_2015["w_bpSaved"].sum()
total_brk_faced = grouped_atp_2015["w_bpFaced"].sum()
rt_games_total = grouped_atp_2015["l_SvGms"].sum()
break_point_opp_total = grouped_atp_2015["l_bpFaced"].sum()
break_point_opp_loss = grouped_atp_2015["l_bpSaved"].sum()
svpt_total = grouped_atp_2015["w_svpt"].sum()

# %%
grouped_atp_2015_losers = atp_2015.groupby(["loser_name"])

# %%
aces_1 = grouped_atp_2015_losers["l_ace"].sum()
service_games_1 = grouped_atp_2015_losers["l_SvGms"].sum()
first_serve_in_l = grouped_atp_2015_losers["l_1stIn"].sum()
first_serves_won_l = grouped_atp_2015_losers["l_1stWon"].sum()
doubfts_l = grouped_atp_2015_losers["l_df"].sum()
total_brk_saved_l = grouped_atp_2015_losers["l_bpSaved"].sum()
total_brk_faced_l = grouped_atp_2015_losers["l_bpFaced"].sum()
rt_games_total_l = grouped_atp_2015_losers["w_SvGms"].sum()
break_point_opp_total_l = grouped_atp_2015_losers["w_bpFaced"].sum()
break_point_opp_loss_l = grouped_atp_2015_losers["w_bpSaved"].sum()
svpt_total_l = grouped_atp_2015_losers["l_svpt"].sum()

# %%
updated_stats_players_l = pd.DataFrame({"aces":aces_1,
                                   "service_games":service_games_1,
                                     "first_serve_in": first_serve_in_l,
                                     "first_serves_won": first_serves_won_l,
                                     "doubfts": doubfts_l,
                                     "total_brk_saved": total_brk_saved_l,
                                     "total_brk_faced": total_brk_faced_l,
                                     "rt_games_total": rt_games_total_l,
                                     "break_point_opp_total": break_point_opp_total_l,
                                     "break_point_opp_loss": break_point_opp_loss_l,
                                     "svpt_total": svpt_total_l})
updated_stats_players_l.head(20)
# Out:
#                            aces  break_point_opp_loss  break_point_opp_total  \
# loser_name
# Adrian Mannarino          124.0                 103.0                  157.0
# Adrian Menendez Maceiras   25.0                   7.0                   14.0
# Adrien Bossel               8.0                   2.0                    2.0
# Albert Montanes            15.0                  27.0                   38.0
# Albert Ramos               70.0                 101.0                  141.0
# Alejandro Falla            28.0                  39.0                   54.0
# Alejandro Gomez GB42        3.0                   4.0                    6.0
# Alejandro Gonzalez         35.0                  55.0                   72.0
# Aleksandr Nedovyesov       11.0                  22.0                   26.0
# Alex Bolt                   3.0                   4.0                    4.0
# Alexander Kudryavtsev      17.0                   7.0                   13.0
# Alexander Sarkissian        9.0                   6.0                    6.0
# Alexander Zverev           88.0                  52.0                   77.0
# Alexandr Dolgopolov       175.0                  85.0                  134.0
# Alexandre Sidorenko         3.0                   6.0                    7.0
# Aljaz Bedene              109.0                  53.0                   80.0
# Andre Ghem                  2.0                   0.0                    1.0
# Andrea Arnaboldi           10.0                   6.0                   10.0
# Andreas Beck                7.0                   3.0                    5.0
# Andreas Haider Maurer     148.0                  61.0                   93.0
#
#                           doubfts  first_serve_in  first_serves_won  \
# loser_name
# Adrian Mannarino             90.0          1449.0             955.0
# Adrian Menendez Maceiras     11.0           199.0             135.0
# Adrien Bossel                 4.0            39.0              28.0
# Albert Montanes              32.0           293.0             193.0
# Albert Ramos                 53.0          1172.0             746.0
# Alejandro Falla              37.0           519.0             331.0
# Alejandro Gomez GB42         16.0            46.0              28.0
# Alejandro Gonzalez           25.0           512.0             329.0
# Aleksandr Nedovyesov          8.0           194.0             125.0
# Alex Bolt                     4.0            39.0              25.0
# Alexander Kudryavtsev         7.0           130.0              92.0
# Alexander Sarkissian          5.0            50.0              40.0
# Alexander Zverev             71.0           840.0             578.0
# Alexandr Dolgopolov          84.0          1300.0             916.0
# Alexandre Sidorenko           4.0            26.0              18.0
# Aljaz Bedene                 52.0           699.0             494.0
# Andre Ghem                    2.0            32.0              26.0
# Andrea Arnaboldi              9.0           154.0              94.0
# Andreas Beck                  4.0            41.0              29.0
# Andreas Haider Maurer       144.0          1023.0             710.0
#
#                           rt_games_total  service_games  svpt_total  \
# loser_name
# Adrian Mannarino                   366.0          357.0      2323.0
# Adrian Menendez Maceiras            56.0           54.0       335.0
# Adrien Bossel                       11.0           10.0        75.0
# Albert Montanes                     82.0           79.0       523.0
# Albert Ramos                       289.0          283.0      1861.0
# Alejandro Falla                    136.0          133.0       842.0
# Alejandro Gomez GB42                13.0           12.0        94.0
# Alejandro Gonzalez                 131.0          127.0       826.0
# Aleksandr Nedovyesov                53.0           50.0       302.0
# Alex Bolt                            9.0            9.0        59.0
# Alexander Kudryavtsev               38.0           37.0       259.0
# Alexander Sarkissian                15.0           14.0        79.0
# Alexander Zverev                   221.0          216.0      1402.0
# Alexandr Dolgopolov                350.0          343.0      2226.0
# Alexandre Sidorenko                  9.0            9.0        49.0
# Aljaz Bedene                       209.0          195.0      1264.0
# Andre Ghem                          10.0           10.0        53.0
# Andrea Arnaboldi                    37.0           38.0       268.0
# Andreas Beck                        14.0           14.0        73.0
# Andreas Haider Maurer              289.0          296.0      1901.0
#
#                           total_brk_faced  total_brk_saved
# loser_name
# Adrian Mannarino                    273.0            164.0
# Adrian Menendez Maceiras             28.0             14.0
# Adrien Bossel                         6.0              5.0
# Albert Montanes                      62.0             32.0
# Albert Ramos                        235.0            144.0
# Alejandro Falla                      85.0             38.0
# Alejandro Gomez GB42                 19.0             13.0
# Alejandro Gonzalez                   88.0             42.0
# Aleksandr Nedovyesov                 30.0             13.0
# Alex Bolt                             7.0              4.0
# Alexander Kudryavtsev                31.0             22.0
# Alexander Sarkissian                  3.0              0.0
# Alexander Zverev                    127.0             64.0
# Alexandr Dolgopolov                 206.0            118.0
# Alexandre Sidorenko                   6.0              2.0
# Aljaz Bedene                        135.0             69.0
# Andre Ghem                            5.0              2.0
# Andrea Arnaboldi                     36.0             21.0
# Andreas Beck                          3.0              0.0
# Andreas Haider Maurer               207.0            111.0

# %%
updated_stats_players = pd.DataFrame({"aces":aces,
                                   "service_games":service_games,
                                     "first_serve_in": first_serve_in,
                                     "first_serves_won": first_serves_won,
                                     "doubfts": doubfts,
                                     "total_brk_saved": total_brk_saved,
                                     "total_brk_faced": total_brk_faced,
                                     "rt_games_total": rt_games_total,
                                     "break_point_opp_total": break_point_opp_total,
                                     "break_point_opp_loss": break_point_opp_loss,
                                     "svpt_total": svpt_total})
updated_stats_players.head()
# Out:
#                            aces  break_point_opp_loss  break_point_opp_total  \
# winner_name
# Adrian Mannarino          126.0                 141.0                  245.0
# Adrian Menendez Maceiras    5.0                   4.0                    7.0
# Albert Montanes            24.0                  66.0                   98.0
# Albert Ramos               69.0                  60.0                  111.0
# Alejandro Falla            29.0                  27.0                   56.0
#
#                           doubfts  first_serve_in  first_serves_won  \
# winner_name
# Adrian Mannarino             50.0          1181.0             907.0
# Adrian Menendez Maceiras      5.0            63.0              48.0
# Albert Montanes              24.0           304.0             220.0
# Albert Ramos                 31.0           665.0             501.0
# Alejandro Falla              27.0           306.0             221.0
#
#                           rt_games_total  service_games  svpt_total  \
# winner_name
# Adrian Mannarino                   318.0          322.0      1963.0
# Adrian Menendez Maceiras            16.0           16.0       116.0
# Albert Montanes                     82.0           80.0       508.0
# Albert Ramos                       170.0          167.0      1038.0
# Alejandro Falla                     80.0           82.0       558.0
#
#                           total_brk_faced  total_brk_saved
# winner_name
# Adrian Mannarino                    134.0             94.0
# Adrian Menendez Maceiras             14.0             11.0
# Albert Montanes                      47.0             30.0
# Albert Ramos                         49.0             38.0
# Alejandro Falla                      36.0             25.0

# %%
frames = [updated_stats_players,updated_stats_players_l]

# %%
results = pd.concat(frames)

# %%
results = results.reset_index()

# %%
full_player_stats = results.groupby(["index"])

# %%
len(full_player_stats.groups)
# Out:
# 282

# %%
total_player_stats = full_player_stats.sum()

# %%
total_player_stats["ace_pct"] = total_player_stats["aces"]/total_player_stats["svpt_total"]
total_player_stats["df_pct"] = total_player_stats["doubfts"]/total_player_stats["svpt_total"]
total_player_stats["first_serve_won_pct"] = total_player_stats["first_serves_won"]/total_player_stats["first_serve_in"]
total_player_stats["broken_pct"] = (total_player_stats["total_brk_faced"]-total_player_stats["total_brk_saved"])/total_player_stats["service_games"]
total_player_stats["breaking_pct"] = (total_player_stats["break_point_opp_total"]-total_player_stats["break_point_opp_loss"])/total_player_stats["rt_games_total"]
total_player_stats["break_conversion_pct"] = (total_player_stats["break_point_opp_total"]-total_player_stats["break_point_opp_loss"])/total_player_stats["break_point_opp_total"]

# %%
total_player_stats = total_player_stats.fillna(0)
total_player_stats.head()
# Out:
#                            aces  break_point_opp_loss  break_point_opp_total  \
# index
# Adrian Mannarino          250.0                 244.0                  402.0
# Adrian Menendez Maceiras   30.0                  11.0                   21.0
# Adrien Bossel               8.0                   2.0                    2.0
# Albert Montanes            39.0                  93.0                  136.0
# Albert Ramos              139.0                 161.0                  252.0
#
#                           doubfts  first_serve_in  first_serves_won  \
# index
# Adrian Mannarino            140.0          2630.0            1862.0
# Adrian Menendez Maceiras     16.0           262.0             183.0
# Adrien Bossel                 4.0            39.0              28.0
# Albert Montanes              56.0           597.0             413.0
# Albert Ramos                 84.0          1837.0            1247.0
#
#                           rt_games_total  service_games  svpt_total  \
# index
# Adrian Mannarino                   684.0          679.0      4286.0
# Adrian Menendez Maceiras            72.0           70.0       451.0
# Adrien Bossel                       11.0           10.0        75.0
# Albert Montanes                    164.0          159.0      1031.0
# Albert Ramos                       459.0          450.0      2899.0
#
#                           total_brk_faced  total_brk_saved   ace_pct  \
# index
# Adrian Mannarino                    407.0            258.0  0.058329
# Adrian Menendez Maceiras             42.0             25.0  0.066519
# Adrien Bossel                         6.0              5.0  0.106667
# Albert Montanes                     109.0             62.0  0.037827
# Albert Ramos                        284.0            182.0  0.047948
#
#                             df_pct  first_serve_won_pct  broken_pct  \
# index
# Adrian Mannarino          0.032664             0.707985    0.219440
# Adrian Menendez Maceiras  0.035477             0.698473    0.242857
# Adrien Bossel             0.053333             0.717949    0.100000
# Albert Montanes           0.054316             0.691792    0.295597
# Albert Ramos              0.028976             0.678824    0.226667
#
#                           breaking_pct  break_conversion_pct
# index
# Adrian Mannarino              0.230994              0.393035
# Adrian Menendez Maceiras      0.138889              0.476190
# Adrien Bossel                 0.000000              0.000000
# Albert Montanes               0.262195              0.316176
# Albert Ramos                  0.198257              0.361111

# %%
total_player_stats = total_player_stats.join(merged_win_lose_grass,how = "outer")

# %%
total_player_stats = total_player_stats.join(merged_win_lose_clay, how = "outer")
total_player_stats = total_player_stats.join(merged_win_lose_hard, how = "outer")
##start here

# %%
total_player_stats = total_player_stats.join(combined_RL_Left, how = "outer")
total_player_stats = total_player_stats.join(combined_RL_Right, how = "outer")

# %%
total_player_stats = total_player_stats.fillna(0)

# %%
total_player_stats.head()
# Out:
#                            aces  break_point_opp_loss  break_point_opp_total  \
# Adrian Mannarino          250.0                 244.0                  402.0
# Adrian Menendez Maceiras   30.0                  11.0                   21.0
# Adrien Bossel               8.0                   2.0                    2.0
# Albert Montanes            39.0                  93.0                  136.0
# Albert Ramos              139.0                 161.0                  252.0
#
#                           doubfts  first_serve_in  first_serves_won  \
# Adrian Mannarino            140.0          2630.0            1862.0
# Adrian Menendez Maceiras     16.0           262.0             183.0
# Adrien Bossel                 4.0            39.0              28.0
# Albert Montanes              56.0           597.0             413.0
# Albert Ramos                 84.0          1837.0            1247.0
#
#                           rt_games_total  service_games  svpt_total  \
# Adrian Mannarino                   684.0          679.0      4286.0
# Adrian Menendez Maceiras            72.0           70.0       451.0
# Adrien Bossel                       11.0           10.0        75.0
# Albert Montanes                    164.0          159.0      1031.0
# Albert Ramos                       459.0          450.0      2899.0
#
#                           total_brk_faced         ...            df_pct  \
# Adrian Mannarino                    407.0         ...          0.032664
# Adrian Menendez Maceiras             42.0         ...          0.035477
# Adrien Bossel                         6.0         ...          0.053333
# Albert Montanes                     109.0         ...          0.054316
# Albert Ramos                        284.0         ...          0.028976
#
#                           first_serve_won_pct  broken_pct  breaking_pct  \
# Adrian Mannarino                     0.707985    0.219440      0.230994
# Adrian Menendez Maceiras             0.698473    0.242857      0.138889
# Adrien Bossel                        0.717949    0.100000      0.000000
# Albert Montanes                      0.691792    0.295597      0.262195
# Albert Ramos                         0.678824    0.226667      0.198257
#
#                           break_conversion_pct  win_pct_grass  win_pct_clay  \
# Adrian Mannarino                      0.393035       0.545455      0.166667
# Adrian Menendez Maceiras              0.476190       0.000000      0.000000
# Adrien Bossel                         0.000000       0.000000      0.000000
# Albert Montanes                       0.316176       0.000000      0.500000
# Albert Ramos                          0.361111       0.333333      0.380952
#
#                           win_pct_hard  Left_hand_win_pct  right_hand_win_pct
# Adrian Mannarino              0.512195           0.636364            0.422222
# Adrian Menendez Maceiras      0.333333           0.000000            0.250000
# Adrien Bossel                 0.000000           0.000000            0.000000
# Albert Montanes               0.000000           0.333333            0.500000
# Albert Ramos                  0.466667           0.333333            0.411765
#
# [5 rows x 22 columns]

# %%
matchups_2016 = pd.read_csv("2016_match_results.csv")
# matchups_2016 = matchups_2016[['Player 1.1', 'Player 2.1', 'Player_1_Win.1']]
matchups_2016.head()
# Out:
#   surface  player_1_win         player_1 Player_1_hand  Player_1_age  \
# 0    Hard             1     Milos Raonic             R     25.021218
# 1    Hard             1    Roger Federer             R     34.406571
# 2    Hard             0    Bernard Tomic             R     23.203285
# 3    Hard             0  Grigor Dimitrov             R     24.637919
# 4    Hard             1    Dominic Thiem             R     22.335387
#
#         player_2 Player_2_hand  Player_2_age
# 0  Roger Federer             R     34.406571
# 1  Dominic Thiem             R     22.335387
# 2   Milos Raonic             R     25.021218
# 3  Roger Federer             R     34.406571
# 4    Marin Cilic             R     27.266256

# %%
matchups_2016 = matchups_2016[['surface', 'player_1_win', 'player_1','player_2', 'Player_1_hand','Player_2_hand']]
# matchups_2016 = matchups_2016[['Player 1.1', 'Player 2.1', 'Player_1_Win.1']]
# matchups_2016.columns = [['player_1', 'player_2', "player_1_win"]]
matchups_2016.head()
# Out:
#   surface  player_1_win         player_1       player_2 Player_1_hand  \
# 0    Hard             1     Milos Raonic  Roger Federer             R
# 1    Hard             1    Roger Federer  Dominic Thiem             R
# 2    Hard             0    Bernard Tomic   Milos Raonic             R
# 3    Hard             0  Grigor Dimitrov  Roger Federer             R
# 4    Hard             1    Dominic Thiem    Marin Cilic             R
#
#   Player_2_hand
# 0             R
# 1             R
# 2             R
# 3             R
# 4             R

# %%
# matchups_2016['ace_pct'] = 0
# ace_pct = total_player_stats.loc['Roger Federer']['ace_pct'] - total_player_stats.loc['Milos Raonic']['ace_pct']
# print(type(ace_pct))
# matchups_2016.loc[0,'ace_pct'] = ace_pct
# matchups_2016.head()

# %%
matchups_2016['ace_pct'] = 0
matchups_2016['df_pct'] = 0
matchups_2016['first_serve_pct'] = 0
matchups_2016['broken_pct'] = 0
matchups_2016['breaking_pct'] = 0
matchups_2016['break_conversion_pct'] = 0
matchups_2016["surface_win_pct"] = 0
matchups_2016["player_hand_win_pct"] = 0
count_unknown_hand = 0

for index, row in matchups_2016.iterrows():
    player_1 = row['player_1']
    player_2 = row['player_2']
    if player_1 in total_player_stats.index and player_2 in total_player_stats.index:
        ace_pct = total_player_stats.loc[player_1]['ace_pct'] - total_player_stats.loc[player_2]['ace_pct']
        df_pct = total_player_stats.loc[player_1]['df_pct'] - total_player_stats.loc[player_2]['df_pct']
        first_serve_pct = total_player_stats.loc[player_1]['first_serve_won_pct'] - total_player_stats.loc[player_2]['first_serve_won_pct']
        broken_pct = total_player_stats.loc[player_1]['broken_pct'] - total_player_stats.loc[player_2]['broken_pct']
        breaking_pct = total_player_stats.loc[player_1]['breaking_pct'] - total_player_stats.loc[player_2]['breaking_pct']
        break_conversion_pct = total_player_stats.loc[player_1]['break_conversion_pct'] - total_player_stats.loc[player_2]['break_conversion_pct']
        if row["surface"] == "Hard":
            surface_win_pct = total_player_stats.loc[player_1]["win_pct_hard"]-total_player_stats.loc[player_2]["win_pct_hard"]
        elif row["surface"] == "Clay":
            surface_win_pct = total_player_stats.loc[player_1]["win_pct_clay"]-total_player_stats.loc[player_2]["win_pct_clay"]
        elif row["surface"] == "Grass":
            surface_win_pct = total_player_stats.loc[player_1]["win_pct_grass"]-total_player_stats.loc[player_2]["win_pct_grass"]
        else:
            print("something went wrong...")
        
        if row["Player_1_hand"] == "R":
            if row["Player_2_hand"] == "R":
                player_hand_win_pct = total_player_stats.loc[player_1]["right_hand_win_pct"]-total_player_stats.loc[player_2]["right_hand_win_pct"]
            elif row["Player_2_hand"] == "L":
                player_hand_win_pct = total_player_stats.loc[player_1]["Left_hand_win_pct"]-total_player_stats.loc[player_2]["right_hand_win_pct"]
            else:
                print("unknown")
                count_unknown_hand+=1   
        elif row["Player_1_hand"] == "L":
            if row["Player_2_hand"] == "R":
                player_hand_win_pct = total_player_stats.loc[player_1]["right_hand_win_pct"]-total_player_stats.loc[player_2]["Left_hand_win_pct"]
            elif row["Player_2_hand"] == "L":
                player_hand_win_pct = total_player_stats.loc[player_1]["Left_hand_win_pct"]-total_player_stats.loc[player_2]["Left_hand_win_pct"]
            else:
                print("unknown")
                count_unknown_hand+=1
            
            
        matchups_2016.loc[index, 'ace_pct'] =  ace_pct
        matchups_2016.loc[index, 'df_pct'] = df_pct
        matchups_2016.loc[index, 'first_serve_pct'] = first_serve_pct
        matchups_2016.loc[index, 'broken_pct'] = broken_pct
        matchups_2016.loc[index, 'breaking_pct'] =  breaking_pct
        matchups_2016.loc[index, 'break_conversion_pct'] = break_conversion_pct
        matchups_2016.loc[index, 'surface_win_pct'] = surface_win_pct
        matchups_2016.loc[index, "player_hand_win_pct"] = player_hand_win_pct
    else: 
        continue
    
len(matchups_2016)
# Out:
# unknown
# unknown
# 2922

# %%
matchups_2016 = matchups_2016[matchups_2016.first_serve_pct != 0]
len(matchups_2016)
# Out:
# 2503

# %%
matchups_2016.head()
# Out:
#   surface  player_1_win         player_1       player_2 Player_1_hand  \
# 0    Hard             1     Milos Raonic  Roger Federer             R
# 1    Hard             1    Roger Federer  Dominic Thiem             R
# 2    Hard             0    Bernard Tomic   Milos Raonic             R
# 3    Hard             0  Grigor Dimitrov  Roger Federer             R
# 4    Hard             1    Dominic Thiem    Marin Cilic             R
#
#   Player_2_hand   ace_pct    df_pct  first_serve_pct  broken_pct  \
# 0             R  0.075908  0.012413         0.012795   -0.022868
# 1             R  0.038115 -0.005608         0.053743   -0.079337
# 2             R -0.086675 -0.018802        -0.085584    0.102987
# 3             R -0.024222  0.010933        -0.048243    0.090955
# 4             R -0.061762 -0.000358        -0.034803    0.015030
#
#    breaking_pct  break_conversion_pct  surface_win_pct  player_hand_win_pct
# 0     -0.146462             -0.078213        -0.174751            -0.156177
# 1      0.067308              0.075400         0.393798             0.252331
# 2      0.078803              0.071856        -0.026140            -0.092308
# 3     -0.059272             -0.037586        -0.289037            -0.248485
# 4      0.016537             -0.048358        -0.210753            -0.017483

# %%
parameter_match_ups = pd.read_csv('matchups_parameters.csv')

# %%
parameter_match_ups.head()
# Out:
#    Unnamed: 0        player_1            player_2  \
# 0           0  Radek Stepanek  Yoshihito Nishioka
# 1           1  Radek Stepanek       Matthew Ebden
# 2           2  Radek Stepanek     Feliciano Lopez
# 3           3  Radek Stepanek     Mikhail Youzhny
# 4           4  Radek Stepanek   Yasutaka Uchiyama
#
#                                      player_1_losses  \
# 0  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 1  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 2  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 3  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 4  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
#
#                                        player_1_wins  \
# 0  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 1  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 2  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 3  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 4  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
#
#                                      player_2_losses  \
# 0  ['Tatsuma Ito', 'Thomaz Bellucci', 'Alexander ...
# 1  ['Austin Krajicek', 'John Isner', 'Tatsuma Ito...
# 2  ['Joao Sousa', 'Roger Federer', 'Novak Djokovi...
# 3  ['Gilles Simon', 'Bastian Trinker', 'Thomaz Be...
# 4                  ['Jiri Vesely', 'Vasek Pospisil']
#
#                                        player_2_wins  \
# 0  ['Paul Henri Mathieu', 'Igor Sijsling', 'Marin...
# 1                                      ['Blaz Rola']
# 2  ['Milos Raonic', 'Andreas Seppi', 'Rafael Nada...
# 3  ['Viktor Troicki', 'Gilles Simon', 'Andrey Gol...
# 4                                            ['Bye']
#
#    player_1_losses_in_player_2_wins  player_2_losses_in_player_1_wins  \
# 0                                 0                                 0
# 1                                 0                                 0
# 2                                 2                                 1
# 3                                 0                                 0
# 4                                 0                                 0
#
#    player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                               0                                   1
# 1                               0                                   1
# 2                               2                                   4
# 3                               0                                   2
# 4                               0                                   0
#
#    parameters_value_previous  parameter_value
# 0                   0.000000         0.000000
# 1                   0.000000         0.000000
# 2                   0.666667         0.066667
# 3                   0.000000         0.000000
# 4                   0.000000         0.000000

# %%
del parameter_match_ups["Unnamed: 0"]
del parameter_match_ups["parameters_value_previous"]

# %%
parameter_match_ups.head(5)
# Out:
#          player_1            player_2  \
# 0  Radek Stepanek  Yoshihito Nishioka
# 1  Radek Stepanek       Matthew Ebden
# 2  Radek Stepanek     Feliciano Lopez
# 3  Radek Stepanek     Mikhail Youzhny
# 4  Radek Stepanek   Yasutaka Uchiyama
#
#                                      player_1_losses  \
# 0  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 1  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 2  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 3  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
# 4  ['Stanislas Wawrinka', 'Aljaz Bedene', 'David ...
#
#                                        player_1_wins  \
# 0  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 1  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 2  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 3  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
# 4  ['Yuichi Sugita', 'Edouard Roger Vasselin', 'S...
#
#                                      player_2_losses  \
# 0  ['Tatsuma Ito', 'Thomaz Bellucci', 'Alexander ...
# 1  ['Austin Krajicek', 'John Isner', 'Tatsuma Ito...
# 2  ['Joao Sousa', 'Roger Federer', 'Novak Djokovi...
# 3  ['Gilles Simon', 'Bastian Trinker', 'Thomaz Be...
# 4                  ['Jiri Vesely', 'Vasek Pospisil']
#
#                                        player_2_wins  \
# 0  ['Paul Henri Mathieu', 'Igor Sijsling', 'Marin...
# 1                                      ['Blaz Rola']
# 2  ['Milos Raonic', 'Andreas Seppi', 'Rafael Nada...
# 3  ['Viktor Troicki', 'Gilles Simon', 'Andrey Gol...
# 4                                            ['Bye']
#
#    player_1_losses_in_player_2_wins  player_2_losses_in_player_1_wins  \
# 0                                 0                                 0
# 1                                 0                                 0
# 2                                 2                                 1
# 3                                 0                                 0
# 4                                 0                                 0
#
#    player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                               0                                   1
# 1                               0                                   1
# 2                               2                                   4
# 3                               0                                   2
# 4                               0                                   0
#
#    parameter_value
# 0         0.000000
# 1         0.000000
# 2         0.066667
# 3         0.000000
# 4         0.000000

# %%
matchups_2016.tail()
# Out:
#      surface  player_1_win            player_1              player_2  \
# 2912    Hard             1  Yoshihito Nishioka       Illya Marchenko
# 2915    Hard             1    Andrey Kuznetsov  Aleksandr Nedovyesov
# 2916    Hard             0      Evgeny Donskoy     Mikhail Kukushkin
# 2917    Hard             1    Andrey Kuznetsov     Mikhail Kukushkin
# 2920    Clay             1       Denis Istomin       Henri Laaksonen
#
#      Player_1_hand Player_2_hand   ace_pct    df_pct  first_serve_pct  \
# 2912             L             R -0.039332 -0.008939        -0.135316
# 2915             R             R  0.022835  0.005833         0.050083
# 2916             R             R  0.028885  0.018216         0.060419
# 2917             R             R  0.021738  0.008873         0.022850
# 2920             R             R  0.047460 -0.042757         0.099285
#
#       broken_pct  breaking_pct  break_conversion_pct  surface_win_pct  \
# 2912    0.150060      0.089054              0.016203         0.228571
# 2915   -0.060524      0.142477              0.301511         0.444444
# 2916   -0.040470      0.002361             -0.044353         0.075556
# 2917    0.028922      0.008445              0.020380        -0.035556
# 2920   -0.184553     -0.010439             -0.021709         0.454545
#
#       player_hand_win_pct
# 2912             0.428571
# 2915             0.307692
# 2916             0.128571
# 2917            -0.063736
# 2920             0.500000

# %%
matchups_2016.head()
# Out:
#   surface  player_1_win         player_1       player_2 Player_1_hand  \
# 0    Hard             1     Milos Raonic  Roger Federer             R
# 1    Hard             1    Roger Federer  Dominic Thiem             R
# 2    Hard             0    Bernard Tomic   Milos Raonic             R
# 3    Hard             0  Grigor Dimitrov  Roger Federer             R
# 4    Hard             1    Dominic Thiem    Marin Cilic             R
#
#   Player_2_hand   ace_pct    df_pct  first_serve_pct  broken_pct  \
# 0             R  0.075908  0.012413         0.012795   -0.022868
# 1             R  0.038115 -0.005608         0.053743   -0.079337
# 2             R -0.086675 -0.018802        -0.085584    0.102987
# 3             R -0.024222  0.010933        -0.048243    0.090955
# 4             R -0.061762 -0.000358        -0.034803    0.015030
#
#    breaking_pct  break_conversion_pct  surface_win_pct  player_hand_win_pct
# 0     -0.146462             -0.078213        -0.174751            -0.156177
# 1      0.067308              0.075400         0.393798             0.252331
# 2      0.078803              0.071856        -0.026140            -0.092308
# 3     -0.059272             -0.037586        -0.289037            -0.248485
# 4      0.016537             -0.048358        -0.210753            -0.017483

# %%
merging_matching = pd.merge(matchups_2016, parameter_match_ups, how='left', left_on=['player_1','player_2'], right_on = ['player_1','player_2'])

# %%
merging_matching.head()
# Out:
#   surface  player_1_win         player_1       player_2 Player_1_hand  \
# 0    Hard             1     Milos Raonic  Roger Federer             R
# 1    Hard             1    Roger Federer  Dominic Thiem             R
# 2    Hard             0    Bernard Tomic   Milos Raonic             R
# 3    Hard             0  Grigor Dimitrov  Roger Federer             R
# 4    Hard             1    Dominic Thiem    Marin Cilic             R
#
#   Player_2_hand   ace_pct    df_pct  first_serve_pct  broken_pct  \
# 0             R  0.075908  0.012413         0.012795   -0.022868
# 1             R  0.038115 -0.005608         0.053743   -0.079337
# 2             R -0.086675 -0.018802        -0.085584    0.102987
# 3             R -0.024222  0.010933        -0.048243    0.090955
# 4             R -0.061762 -0.000358        -0.034803    0.015030
#
#         ...         player_hand_win_pct  \
# 0       ...                   -0.156177
# 1       ...                    0.252331
# 2       ...                   -0.092308
# 3       ...                   -0.248485
# 4       ...                   -0.017483
#
#                                      player_1_losses  \
# 0  ['Feliciano Lopez', 'Rafael Nadal', 'Nick Kyrg...
# 1  ['Albert Ramos', 'John Isner', 'Novak Djokovic...
# 2  ['Steve Johnson', 'Marcos Baghdatis', 'Alexand...
# 3  ['Benoit Paire', 'Tomas Berdych', 'Andy Murray...
# 4  ['Martin Klizan', 'Feliciano Lopez', 'Kevin An...
#
#                                        player_1_wins  \
# 0  ['Thomaz Bellucci', 'Roberto Bautista Agut', '...
# 1  ['Roberto Bautista Agut', 'Kevin Anderson', 'F...
# 2  ['Sergiy Stakhovsky', 'Fernando Verdasco', 'Da...
# 3  ['Filip Krajinovic', 'Nicolas Almagro', 'Lukas...
# 4  ['Dusan Lajovic', 'Andreas Haider Maurer', 'Ga...
#
#                                      player_2_losses  \
# 0  ['Albert Ramos', 'John Isner', 'Novak Djokovic...
# 1  ['Martin Klizan', 'Feliciano Lopez', 'Kevin An...
# 2  ['Feliciano Lopez', 'Rafael Nadal', 'Nick Kyrg...
# 3  ['Albert Ramos', 'John Isner', 'Novak Djokovic...
# 4  ['Kei Nishikori', 'Richard Gasquet', 'Stanisla...
#
#                                        player_2_wins  \
# 0  ['Roberto Bautista Agut', 'Kevin Anderson', 'F...
# 1  ['Dusan Lajovic', 'Andreas Haider Maurer', 'Ga...
# 2  ['Thomaz Bellucci', 'Roberto Bautista Agut', '...
# 3  ['Roberto Bautista Agut', 'Kevin Anderson', 'F...
# 4  ['Donald Young', 'Steve Johnson', 'Joao Sousa'...
#
#   player_1_losses_in_player_2_wins player_2_losses_in_player_1_wins  \
# 0                               10                                0
# 1                                3                               13
# 2                                5                                1
# 3                                9                                2
# 4                                4                                1
#
#   player_1_wins_in_player_2_wins  player_1_losses_in_player_2_losses  \
# 0                             12                                   4
# 1                             12                                   2
# 2                              8                                   5
# 3                              4                                   2
# 4                              6                                   5
#
#    parameter_value
# 0         0.100000
# 1         0.018750
# 2         0.083333
# 3         0.081818
# 4         0.080000
#
# [5 rows x 23 columns]

# %%
merging_matching = merging_matching.dropna(axis=0,how="any")

# %%
del merging_matching["player_1_losses"]
del merging_matching["player_1_wins"]
del merging_matching["player_2_losses"]
del merging_matching["player_2_wins"]
del merging_matching["player_1_losses_in_player_2_wins"]
del merging_matching["player_1_losses_in_player_2_losses"]
del merging_matching["player_1_wins_in_player_2_wins"]
del merging_matching["player_2_losses_in_player_1_wins"]

# %%
merging_matching.head()
# Out:
#   surface  player_1_win         player_1       player_2 Player_1_hand  \
# 0    Hard             1     Milos Raonic  Roger Federer             R
# 1    Hard             1    Roger Federer  Dominic Thiem             R
# 2    Hard             0    Bernard Tomic   Milos Raonic             R
# 3    Hard             0  Grigor Dimitrov  Roger Federer             R
# 4    Hard             1    Dominic Thiem    Marin Cilic             R
#
#   Player_2_hand   ace_pct    df_pct  first_serve_pct  broken_pct  \
# 0             R  0.075908  0.012413         0.012795   -0.022868
# 1             R  0.038115 -0.005608         0.053743   -0.079337
# 2             R -0.086675 -0.018802        -0.085584    0.102987
# 3             R -0.024222  0.010933        -0.048243    0.090955
# 4             R -0.061762 -0.000358        -0.034803    0.015030
#
#    breaking_pct  break_conversion_pct  surface_win_pct  player_hand_win_pct  \
# 0     -0.146462             -0.078213        -0.174751            -0.156177
# 1      0.067308              0.075400         0.393798             0.252331
# 2      0.078803              0.071856        -0.026140            -0.092308
# 3     -0.059272             -0.037586        -0.289037            -0.248485
# 4      0.016537             -0.048358        -0.210753            -0.017483
#
#    parameter_value
# 0         0.100000
# 1         0.018750
# 2         0.083333
# 3         0.081818
# 4         0.080000

# %%
len(merging_matching)
# Out:
# 2503

# %%
#parameter_match_ups[parameter_match_ups.player_1==matchups_2016.player_1 and parameter_match_ups.player_2==matchups_2016.player_2]

# %%
#parameter_match_ups.player_1==matchups_2016.player_1

# %%
merging_matching.to_csv("merging_matching_first_inputs.csv")

# %%
##if you ran the previous code, no need to run this
merging_matching = pd.read_csv("merging_matching_first_inputs.csv")
del merging_matching["Unnamed: 0"]
merging_matching.head()

# %%
merging_matching.head()
# Out:
#   surface  player_1_win         player_1       player_2 Player_1_hand  \
# 0    Hard             1     Milos Raonic  Roger Federer             R
# 1    Hard             1    Roger Federer  Dominic Thiem             R
# 2    Hard             0    Bernard Tomic   Milos Raonic             R
# 3    Hard             0  Grigor Dimitrov  Roger Federer             R
# 4    Hard             1    Dominic Thiem    Marin Cilic             R
#
#   Player_2_hand   ace_pct    df_pct  first_serve_pct  broken_pct  \
# 0             R  0.075908  0.012413         0.012795   -0.022868
# 1             R  0.038115 -0.005608         0.053743   -0.079337
# 2             R -0.086675 -0.018802        -0.085584    0.102987
# 3             R -0.024222  0.010933        -0.048243    0.090955
# 4             R -0.061762 -0.000358        -0.034803    0.015030
#
#    breaking_pct  break_conversion_pct  surface_win_pct  player_hand_win_pct  \
# 0     -0.146462             -0.078213        -0.174751            -0.156177
# 1      0.067308              0.075400         0.393798             0.252331
# 2      0.078803              0.071856        -0.026140            -0.092308
# 3     -0.059272             -0.037586        -0.289037            -0.248485
# 4      0.016537             -0.048358        -0.210753            -0.017483
#
#    parameter_value
# 0         0.100000
# 1         0.018750
# 2         0.083333
# 3         0.081818
# 4         0.080000

# %%
X = merging_matching.drop(["player_1_win", "player_1", "player_2", "surface", "Player_1_hand", "Player_2_hand"], axis=1)
y = merging_matching["player_1_win"]
print(X.shape, y.shape)
# Out:
# (2503, 9) (2503,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6766116142781033
# Testing Data Score: 0.6645367412140575

# %%
predictions_prob = classifier.predict_proba(X_test)
predictions1 = classifier.predict(X_test)

# %%
clean_data = [[item for item in row] for row in predictions_prob]

# %%
player_prob = pd.DataFrame(clean_data, columns=["player_1_prob","player_2_prob"])

# %%
player_prob.head()
# Out:
#    player_1_prob  player_2_prob
# 0       0.435142       0.564858
# 1       0.381546       0.618454
# 2       0.693685       0.306315
# 3       0.686183       0.313817
# 4       0.781783       0.218217

# %%
#pd.DataFrame({"Prediction": predictions1, "Actual": y_test}).reset_index(drop=True).head()

# %%
predictions_dataframe = X_test

# %%
player_prob['index'] = predictions_dataframe.index
player_prob = player_prob.set_index('index')

# %%
player_prob.head()
# Out:
#        player_1_prob  player_2_prob
# index
# 2137        0.435142       0.564858
# 1137        0.381546       0.618454
# 714         0.693685       0.306315
# 195         0.686183       0.313817
# 1104        0.781783       0.218217

# %%
player_prob_merge = predictions_dataframe.join(player_prob, how = "inner")

# %%
player_prob_merge.head()
# Out:
#         ace_pct    df_pct  first_serve_pct  broken_pct  breaking_pct  \
# index
# 2137   0.078340 -0.022998         0.055498   -0.073053     -0.063839
# 1137   0.053030  0.007643         0.095731   -0.153238     -0.089844
# 714   -0.051361 -0.002934        -0.017604    0.097159     -0.037721
# 195   -0.041406 -0.018410        -0.090637    0.104721     -0.006269
# 1104   0.045339 -0.021420         0.021526   -0.061442     -0.131637
#
#        break_conversion_pct  surface_win_pct  player_hand_win_pct  \
# index
# 2137              -0.026715         0.099206             0.038825
# 1137              -0.088855         0.166667             0.179402
# 714               -0.076040        -0.215385            -0.287302
# 195                0.021254        -0.298387            -0.049100
# 1104              -0.062352        -0.625000            -0.071429
#
#        parameter_value  player_1_prob  player_2_prob
# index
# 2137          0.028571       0.435142       0.564858
# 1137          0.033333       0.381546       0.618454
# 714           0.100000       0.693685       0.306315
# 195           0.050000       0.686183       0.313817
# 1104          0.066667       0.781783       0.218217

# %%
player_prob_merge["Prediction"] = predictions1

# %%
player_prob_merge["Actual"] = y_test

# %%
player_prob_merge.head(5)

##multiply the parameters_value by .01
# Out:
#         ace_pct    df_pct  first_serve_pct  broken_pct  breaking_pct  \
# index
# 2137   0.078340 -0.022998         0.055498   -0.073053     -0.063839
# 1137   0.053030  0.007643         0.095731   -0.153238     -0.089844
# 714   -0.051361 -0.002934        -0.017604    0.097159     -0.037721
# 195   -0.041406 -0.018410        -0.090637    0.104721     -0.006269
# 1104   0.045339 -0.021420         0.021526   -0.061442     -0.131637
#
#        break_conversion_pct  surface_win_pct  player_hand_win_pct  \
# index
# 2137              -0.026715         0.099206             0.038825
# 1137              -0.088855         0.166667             0.179402
# 714               -0.076040        -0.215385            -0.287302
# 195                0.021254        -0.298387            -0.049100
# 1104              -0.062352        -0.625000            -0.071429
#
#        parameter_value  player_1_prob  player_2_prob  Prediction  Actual
# index
# 2137          0.028571       0.435142       0.564858           1       0
# 1137          0.033333       0.381546       0.618454           1       0
# 714           0.100000       0.693685       0.306315           0       0
# 195           0.050000       0.686183       0.313817           0       0
# 1104          0.066667       0.781783       0.218217           0       0

# %%
players = merging_matching[["player_1", "player_2"]]

# %%
players.head()
# Out:
#           player_1       player_2
# 0     Milos Raonic  Roger Federer
# 1    Roger Federer  Dominic Thiem
# 2    Bernard Tomic   Milos Raonic
# 3  Grigor Dimitrov  Roger Federer
# 4    Dominic Thiem    Marin Cilic

# %%
final_result_1 = players.join(player_prob_merge, how  ="inner")

# %%
final_result_1 = final_result_1.rename(index=str, columns={"player_1_prob": "player_2_prob","player_2_prob":"player_1_prob"})

# %%
final_result_1.to_csv("results_predicting_all_2016.csv")

# %%
final_result_1
# Out:
#                     player_1                player_2   ace_pct    df_pct  \
# 1              Roger Federer           Dominic Thiem  0.038115 -0.005608
# 6              Bernard Tomic           Kei Nishikori  0.043269 -0.015663
# 9                Hyeon Chung             Marin Cilic -0.077955  0.020185
# 14         Mikhail Kukushkin           Kei Nishikori -0.023097 -0.009830
# 25               Borna Coric      Stanislas Wawrinka -0.044049  0.001996
